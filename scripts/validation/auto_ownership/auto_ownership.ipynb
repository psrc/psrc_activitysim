# %% [raw]
# ---
# title: Auto Ownership Summary
# ---

# %% [markdown]
# compare between model results and survey data: see how the results change/improve when we use coefficients estimated from our survey
#
# - variables: income, hhsize, number of adults/drivers/workers, household/employment density
# - add total number of households in graphs

# %%
import os
import pandas as pd
import numpy as np
import pyodbc
from pathlib import Path
import plotly.express as px

# to show plotly figures in quarto HTML file
import plotly.io as pio
pio.renderers.default = "plotly_mimetype+notebook_connected"

# path
## landuse data
p_landuse = "R:/e2projects_two/activitysim/estimation/2017_2019_data/validation_data/survey_outputs/final_land_use.csv"
## survey data
p_model_survey_data = "R:/e2projects_two/activitysim/estimation/2017_2019_data/validation_data/survey_outputs/final_households.csv"
## psrc model results
p_psrc_model_data = "R:/e2projects_two/activitysim/estimation/2017_2019_data/validation_data/model_outputs/pipeline.parquetpipeline/households/mp_households.parquet"


p_acs_auto_ownership = "R:/e2projects_two/activitysim\estimation/2017_2019_data/validation_data/auto_ownership/bg_auto_ownership.csv"
p_maz_bg = "R:/e2projects_two/activitysim\estimation/2017_2019_data/validation_data/auto_ownership/maz_bg_lookup.csv"

# %% [markdown]
# ## Household data
#
# - income, hh density, employment density grouped into very low, low, medium, medium-high and high

# %%
# read data

# land use
land_use = pd.read_csv(p_landuse)

# model data
hh_data_model = pd.read_parquet(p_psrc_model_data).reset_index()
# add weight to model data with all 1
hh_data_model['hh_weight_2017_2019'] = np.repeat(1, len(hh_data_model))
# add employment and household density from landuse data and block group id
hh_data_model = hh_data_model.merge(land_use[['zone_id','log_emptot_1','log_hh_1']],how="left",left_on='home_zone_id',right_on='zone_id').\
    merge(pd.read_csv(p_maz_bg)[['MAZ', 'block_group_id']], how="left",left_on='home_zone_id',right_on='MAZ')


# survey data
hh_data_survey = pd.read_csv(p_model_survey_data).groupby('household_id_elmer').first().reset_index() # remove duplicates
hh_data_survey = hh_data_survey.merge(land_use[['zone_id','log_emptot_1','log_hh_1']],how="left",left_on='home_zone_id',right_on='zone_id').\
    merge(pd.read_csv(p_maz_bg)[['MAZ', 'block_group_id']], how="left",left_on='home_zone_id',right_on='MAZ')

# grouping income, hh density, employment density into very low, low, medium, medium-high and high
var_group = hh_data_model[['income','log_emptot_1','log_hh_1']].quantile([.125, .25, .50, .75])

print(f"household counts \n"
      f"- model results: {len(hh_data_model)}\n"
      f"- survey results: {hh_data_survey['hh_weight_2017_2019'].sum()}\n"
      f"group dividers:\n"
      f"{var_group}")
# var_group['income'].loc[0.125]
# Out:
# household counts
# - model results: 1605263
# - survey results: 1505466.8803424172
# group dividers:
#          income  log_emptot_1  log_hh_1
# 0.125   24000.0      1.321043  4.434358
# 0.250   43000.0      2.922615  5.089858
# 0.500   82000.0      4.726863  5.721498
# 0.750  135000.0      6.239594  6.457123

# %%
# process model and survey data for summary
def data_process(df: pd.DataFrame, var_group_df: pd.DataFrame, data_source: str) -> pd.DataFrame:
    
    def var_grouping(df: pd.DataFrame, group_var:str) -> pd.Series:
        df['temp'] = np.where(df[group_var]<var_group_df[group_var].loc[0.125], 'very low',
                     np.where(df[group_var]<var_group_df[group_var].loc[0.250], 'low',
                     np.where(df[group_var]<var_group_df[group_var].loc[0.500], 'medium',
                     np.where(df[group_var]<var_group_df[group_var].loc[0.750], 'medium-high',
                     np.where(df[group_var]>=var_group_df[group_var].loc[0.750],'high', np.nan)))))
        df['temp'] = df['temp'].astype(pd.CategoricalDtype(['very low', 'low', 'medium', 'medium-high', 'high']))
        return df['temp']
        
        
    # add data source
    df['source'] = data_source
    # add auto_ownership with 4+
    df['auto_ownership_simple'] = np.where(df['auto_ownership']>=4, "4+", df['auto_ownership'])
    # add auto_ownership with 2+
    df['auto_ownership_2'] = np.where(df['auto_ownership']<2, df['auto_ownership'], "2+")
    # add hhsize with 4+
    df['hhsize_simple'] = np.where(df['hhsize']>=4, "4+", df['hhsize'])
    # add num_workers with 4+
    df['num_workers_simple'] = np.where(df['num_workers']>=4, "4+", df['num_workers'])
    # add num_adults with 4+
    df['num_adults_simple'] = np.where(df['num_adults']>=4, "4+",df['num_adults'])
    # add num_drivers with 4+
    df['num_drivers_simple'] = np.where(df['num_drivers']>=4, "4+",df['num_drivers'])

    # add income groups
    df['hhincome_group'] = var_grouping(df, 'income')
    # add hh density groups
    df['hh_density_group'] = var_grouping(df, 'log_hh_1')
    # add employment density groups
    df['emp_density_group'] = var_grouping(df, 'log_emptot_1')

    return df

# match columns and concat all source into hh_data
col_list = ['household_id', 'home_zone_id', 'auto_ownership_simple', 'auto_ownership_2',
            'hhincome_group', 'hhsize_simple', 'hh_density_group', 'emp_density_group',
            'num_workers_simple','num_adults_simple','num_drivers_simple', 'block_group_id',
            'source', 'hh_weight_2017_2019']

# combine both sets of data
hh_data = pd.concat([data_process(hh_data_model,  var_group, "model results")[col_list].copy(),
                     data_process(hh_data_survey, var_group, "survey data")[col_list].copy()])

# hh_data

# %% [markdown]
# ## Auto ownership across all households

# %%
unweight_plot = hh_data.loc[hh_data['source']=="survey data"].\
    groupby(['auto_ownership_simple'])['hh_weight_2017_2019'].count().reset_index()
unweight_plot['source']="unweighted survey"
unweight_plot['hh_weight_2017_2019'] = unweight_plot['hh_weight_2017_2019'].astype('float64')

unweight_plot2 = hh_data.groupby(['source','auto_ownership_simple'])['hh_weight_2017_2019'].\
    sum().reset_index()

df_plot = pd.concat([unweight_plot[['source','auto_ownership_simple','hh_weight_2017_2019']],unweight_plot2]).reset_index(drop=True)
# df_plot.groupby(['source'])['hh_weight_2017_2019'].sum()
df_plot['percentage'] = df_plot.groupby(['source'], group_keys=False)['hh_weight_2017_2019'].\
        apply(lambda x: 100 * x / float(x.sum()))
df_plot['source'] = df_plot['source'].astype(pd.CategoricalDtype(['model results', 'survey data', 'unweighted survey']))

fig = px.bar(df_plot.sort_values(by=['source']), x="auto_ownership_simple", y="percentage", color="source",
             barmode="group",template="simple_white",
             title="Auto ownership")
fig.update_layout(height=400, width=700, font=dict(size=11))
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="f3d8d76d-c59a-4ddc-9273-c1b5e0b3ec44" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f3d8d76d-c59a-4ddc-9273-c1b5e0b3ec44")) {                    Plotly.newPlot(                        "f3d8d76d-c59a-4ddc-9273-c1b5e0b3ec44",                        [{"alignmentgroup":"True","hovertemplate":"source=model results<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[12.995191442149977,27.359566625531144,40.51909251007467,13.135604570715204,5.990544851529002],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[6.901188400071165,31.38536583438757,38.04214257429621,15.22925829990623,8.442044891338835],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=unweighted survey<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"unweighted survey","marker":{"color":"#2CA02C","pattern":{"shape":""}},"name":"unweighted survey","offsetgroup":"unweighted survey","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[16.88289806234204,47.615838247683236,27.49789385004212,5.678180286436394,2.325189553496209],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6 ...

# %% [markdown]
# ## Auto ownership distribution within groups

# %%
# auto ownership in Income groups
def plot_auto(df:pd.DataFrame, var:str, title_cat:str,sub_name:str):
    print(f"n=\n"
          f"{df.loc[df['source']=='model results',var].value_counts()[df[var].sort_values().unique()]}")
    df_plot = df.groupby(['source',var,'auto_ownership_simple'])['hh_weight_2017_2019'].sum().reset_index()
    df_plot['percentage'] = df_plot.groupby(['source',var], group_keys=False)['hh_weight_2017_2019'].\
        apply(lambda x: 100 * x / float(x.sum()))

    fig = px.bar(df_plot, x="auto_ownership_simple", y="percentage", color="source",
                 facet_col=var, barmode="group",template="simple_white",
                 title="Auto ownership in each "+ title_cat+ " group")
    fig.for_each_annotation(lambda a: a.update(text = sub_name + "=<br>" + a.text.split("=")[-1]))
    fig.update_xaxes(title_text="n of cars")
    fig.update_layout(height=400, width=700, font=dict(size=11))
    fig.show()

# %% [markdown]
# ### Income

# %%
plot_auto(hh_data,'hhincome_group','income level', 'Income')
# Out:
# n=
# very low       197507
# low            200173
# medium         403002
# medium-high    402988
# high           401593
# Name: hhincome_group, dtype: int64
# <div>                            <div id="458129cd-e4c7-4191-9d7a-e75fcedd6857" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("458129cd-e4c7-4191-9d7a-e75fcedd6857")) {                    Plotly.newPlot(                        "458129cd-e4c7-4191-9d7a-e75fcedd6857",                        [{"alignmentgroup":"True","hovertemplate":"source=model results<br>hhincome_group=very low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[36.9814740743366,41.635486337193115,17.4049527358524,2.920402821165832,1.0576840314520497],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>hhincome_group=low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[20.27596129348114,40.31562698266,31.729054367971706,4.988185219784886,2.6911721361022716],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>hhincome_group=medium<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[11.931702572195672,33.77427407308152,40.233299090327094,8.880601088828342,5.180123175567367],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>hhincome_group=medium-high<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":[7.164233178159151,19.813245059406235,47.02770305815558,17.469254667632782,8.525564036646253],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>hhincome_group=high<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x5","y":[4.487877029729104,15.015948983174507,50.02378029497526,22.14182020104932,8.330573491071807],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>hhincome_group=very low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[26.053397021817133,59.336363717491025,12.550825522704853,1.7451664645028664,0.3142472734841359],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>hhincome_group=low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[14.706484401672876,40.523109 ...

# %% [markdown]
# ### Household size

# %%
plot_auto(hh_data,'hhsize_simple','household size', 'HH size')
# Out:
# n=
# 1     452162
# 2     533682
# 3     254336
# 4+    365083
# Name: hhsize_simple, dtype: int64
# <div>                            <div id="d02a77de-f5dc-4644-8c65-52c0579e2ae3" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d02a77de-f5dc-4644-8c65-52c0579e2ae3")) {                    Plotly.newPlot(                        "d02a77de-f5dc-4644-8c65-52c0579e2ae3",                        [{"alignmentgroup":"True","hovertemplate":"source=model results<br>hhsize_simple=1<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[30.141851814172796,47.19503186910886,17.30132120788567,3.634759223464157,1.7270358853685184],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>hhsize_simple=2<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[8.994307471490513,26.150404173271724,48.949186969019,11.689732837157708,4.216368549061051],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>hhsize_simple=3<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[4.677670483140413,15.145712757926523,45.41944514343231,22.853626698540513,11.903544916960241],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>hhsize_simple=4+<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":[3.401692217934004,13.069356831186333,53.53768868996913,20.246081028149764,9.74518123276077],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>hhsize_simple=1<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[16.63373133039795,72.89651563293485,9.306870956014397,1.0270817541806332,0.1358003264721735],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>hhsize_simple=2<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[5.102741223245548,26.1748752867484,44.762399960207475,14.302539652237416,9.65744387756116],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>hhsize_simple=3<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[4.496831995216998,18.831867554869298,44.22267309140192,21.699925982578545,10.74 ...

# %% [markdown]
# ### Number of adults

# %%
plot_auto(hh_data,'num_adults_simple','number of adults','num adults')
# Out:
# n=
# 0         75
# 1     504125
# 2     762899
# 3     240181
# 4+     97983
# Name: num_adults_simple, dtype: int64
# <div>                            <div id="ad65284e-f157-4d55-9621-11f5b9761fbb" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ad65284e-f157-4d55-9621-11f5b9761fbb")) {                    Plotly.newPlot(                        "ad65284e-f157-4d55-9621-11f5b9761fbb",                        [{"alignmentgroup":"True","hovertemplate":"source=model results<br>num_adults_simple=0<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3"],"xaxis":"x","y":[28.0,56.0,13.333333333333334,2.6666666666666665],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>num_adults_simple=1<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[28.713513513513515,47.069675179766925,18.82608480039673,3.6865856682370444,1.7041408380857923],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>num_adults_simple=2<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[6.6184383516035545,22.27804729066364,53.194721712834856,12.895809274884355,5.012983370013593],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>num_adults_simple=3<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":[3.257543269450956,9.250939916146573,43.61918719632277,28.332799014076883,15.539530604002815],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>num_adults_simple=4+<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x5","y":[5.631589153220457,9.882326526030026,45.85897553657267,26.373962830286885,12.25314595388996],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>num_adults_simple=0<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3"],"xaxis":"x","y":[14.448576133034646,13.142226330959534,41.932888172633305,30.476309363372508],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>num_adults_simple=1<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[11.042386428510126,50.43387888461417,23.120301388266107,10.088409101334069,5.315024197275522],"yaxis":"y2", ...

# %% [markdown]
# ### Number of workers

# %%
plot_auto(hh_data,'num_workers_simple','number of workers','num workers')
# Out:
# n=
# 0     355309
# 1     637690
# 2     504466
# 3      99225
# 4+      8573
# Name: num_workers_simple, dtype: int64
# <div>                            <div id="28b5a628-91c2-4bbf-b6d4-a1328f64af29" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("28b5a628-91c2-4bbf-b6d4-a1328f64af29")) {                    Plotly.newPlot(                        "28b5a628-91c2-4bbf-b6d4-a1328f64af29",                        [{"alignmentgroup":"True","hovertemplate":"source=model results<br>num_workers_simple=0<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[21.94062069916608,39.85460542795145,27.496911139318172,5.693917125656823,5.013945607907483],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>num_workers_simple=1<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[15.621383430820618,32.810142859383085,36.63519892110587,9.23144474587966,5.70183004281077],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>num_workers_simple=2<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[5.362303901551344,15.919606078506778,53.23966332716179,18.866682789325743,6.611743903454346],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>num_workers_simple=3<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":[3.549508692365835,7.591836734693878,46.638447971781304,34.204081632653065,8.01612496850592],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>num_workers_simple=4+<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x5","y":[5.3773474862941795,6.030561063804969,49.77254170068821,30.876006065554648,7.943543683657996],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>num_workers_simple=0<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[16.720428145673907,35.48366772943558,33.461950074700034,10.331241113449286,4.0027129367412115],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>num_workers_simple=1<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[7.385552652414711,47.9701669082149 ...

# %% [markdown]
# ### Number of drivers

# %%
plot_auto(hh_data.loc[hh_data['num_drivers_simple']!="0"],'num_drivers_simple','number of drivers','num drivers')
# Out:
# n=
# 1     493312
# 2     708568
# 3     274525
# 4+    128847
# Name: num_drivers_simple, dtype: int64
# <div>                            <div id="5d73f3d2-3482-480c-9bff-38765627e703" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d73f3d2-3482-480c-9bff-38765627e703")) {                    Plotly.newPlot(                        "5d73f3d2-3482-480c-9bff-38765627e703",                        [{"alignmentgroup":"True","hovertemplate":"source=model results<br>num_drivers_simple=1<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[29.194302996886353,47.408739296834455,18.102336857810066,3.608669564089258,1.685951284379865],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>num_drivers_simple=2<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[7.131990154791072,23.800115161847557,54.06368901785009,11.219388964785313,3.784816700725971],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>num_drivers_simple=3<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[2.939622985156179,8.849831527183317,43.33412257535743,28.7766141517166,16.099808760586466],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>num_drivers_simple=4+<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":[4.641163550567728,9.606742881091527,45.8644749198662,26.824838762252906,13.062779886221643],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>num_drivers_simple=1<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[11.24163908112005,51.09416025384153,22.393828936603914,9.904872516591794,5.365499211842705],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>num_drivers_simple=2<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[3.3020114847411515,17.219324580589866,55.68803803215167,16.180248659461796,7.610377243055531],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>num_drivers_simple=3<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[2.2953459576085447,5.5521134977112325,38.5 ...

# %% [markdown]
# ### Household density

# %%
plot_auto(hh_data.dropna(subset=['hh_density_group']),'hh_density_group','household density','density')
# Out:
# n=
# very low       200617
# low            200583
# medium         401416
# medium-high    401303
# high           401344
# Name: hh_density_group, dtype: int64
# <div>                            <div id="0fbd748d-8fb5-44be-8587-25bf65148668" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0fbd748d-8fb5-44be-8587-25bf65148668")) {                    Plotly.newPlot(                        "0fbd748d-8fb5-44be-8587-25bf65148668",                        [{"alignmentgroup":"True","hovertemplate":"source=model results<br>hh_density_group=very low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.534849987787675,10.117288166007866,45.11382385341222,28.06990434509538,16.164133647696854],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>hh_density_group=low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[1.751394684494698,17.621632939979957,49.74299915745602,21.08304292985946,9.800930288209868],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>hh_density_group=medium<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[4.041692408872591,24.460161029953962,48.644548299021466,16.1234230822887,6.730175179863284],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>hh_density_group=medium-high<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":[10.466405683486045,35.14999887865279,42.03058536816321,8.995945706859905,3.357064362838055],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>hh_density_group=high<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x5","y":[36.326692313825546,35.95543972253229,23.974196699091053,2.8494259288789667,0.8942453356721416],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>hh_density_group=very low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[2.4068549961318997,15.82326727358648,28.83255727020117,29.715037367542582,23.22228309253788],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>hh_density_group=low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[2.0925293983 ...

# %% [markdown]
# ### Employment density

# %%
plot_auto(hh_data.dropna(subset=['emp_density_group']),'emp_density_group','employment density','density')
# Out:
# n=
# very low       200546
# low            200554
# medium         401485
# medium-high    401336
# high           401342
# Name: emp_density_group, dtype: int64
# <div>                            <div id="8401a5c4-3dc4-4e47-9767-fc46e10f967c" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8401a5c4-3dc4-4e47-9767-fc46e10f967c")) {                    Plotly.newPlot(                        "8401a5c4-3dc4-4e47-9767-fc46e10f967c",                        [{"alignmentgroup":"True","hovertemplate":"source=model results<br>emp_density_group=very low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.5375325361762389,11.964337359009903,47.21310821457421,25.740229174354013,14.544792715885633],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>emp_density_group=low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[1.074523569711898,15.966273422619345,48.76292669306022,22.598402425281968,11.597873889326566],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>emp_density_group=medium<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[3.5747288192585027,24.998443279325503,48.409778696588916,16.096491774287955,6.920557430539123],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>emp_density_group=medium-high<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":[11.107899615284948,34.975432056929854,41.790170829429705,9.093627284868539,3.0328702134869534],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>emp_density_group=high<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x5","y":[36.488082483268634,35.491924592990514,23.89009871879843,3.1885524066756035,0.9413417982668149],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>emp_density_group=very low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[3.072036625839795,15.323018215246888,41.512948633158594,25.079864359706647,15.012132166048072],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>emp_density_group=low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2 ...

# %% [markdown]
# ## Validate auto ownership with ACS vehicle ownership data
#
# - TO-DO: get auto ownership values [0,1,2,3,4+] from ACS data
# - household counts in ACS data

# %%
print(f"n=\n"
      f"{hh_data.loc[hh_data['source']=='model results','auto_ownership_2'].value_counts()[hh_data['auto_ownership_2'].sort_values().unique()]}")
      
df = hh_data.groupby(['source','block_group_id','auto_ownership_2'])['hh_weight_2017_2019'].sum().reset_index()
# df_plot = df_plot.loc[df_plot['auto_ownership_2']!="-1"]

df['percentage'] = df.groupby(['source','block_group_id'], group_keys=False)['hh_weight_2017_2019'].\
    apply(lambda x: 100 * x / float(x.sum()))

# acs auto ownership data
acs_auto_ownership = pd.read_csv(p_acs_auto_ownership)[['cars_none_control', 'cars_one_control', 'cars_two_or_more_control', 'block_group_id']]

# calculate percentage of households having 0, 1 or 2+ vehicle(s) in each block group
acs_auto_ownership['total'] = acs_auto_ownership['cars_one_control'] + acs_auto_ownership['cars_two_or_more_control'] + acs_auto_ownership['cars_none_control']
acs_auto_ownership['0'] = 100 * acs_auto_ownership['cars_none_control']/acs_auto_ownership['total']
acs_auto_ownership['1'] = 100 * acs_auto_ownership['cars_one_control']/acs_auto_ownership['total']
acs_auto_ownership['2+'] = 100 * acs_auto_ownership['cars_two_or_more_control']/acs_auto_ownership['total']
acs_auto_ownership['source'] = "acs data"
bg_auto_ownership = acs_auto_ownership[['source','block_group_id','0','1','2+']]
bg_auto_ownership = pd.melt(bg_auto_ownership, id_vars=['source','block_group_id'], value_vars=['0','1','2+'], var_name='auto_ownership_2',value_name='percentage')

# combine both sets of data
col_list = ['source','block_group_id','auto_ownership_2','percentage']
bg_auto_ownership = pd.concat([df[col_list].copy(),
                               bg_auto_ownership[col_list].copy()])

# bg_auto_ownership
# Out:
# n=
# 0     208607
# 1     439193
# 2+    957463
# Name: auto_ownership_2, dtype: int64

# %% [markdown]
# - scatterplot

# %%
df_plot = pd.pivot(bg_auto_ownership, index=['block_group_id','auto_ownership_2'], columns='source', values='percentage').reset_index()



fig = px.scatter(df_plot, x="acs data", y="model results", trendline="ols", trendline_color_override='rgb(136, 136, 136)',
                 template="plotly_white",
                 facet_col='auto_ownership_2', height=400, width=1000,
                 title="Auto ownership model results validation with acs data")
fig.update_xaxes(dtick=20)
fig.update_yaxes(dtick=20,range=[0, 100])
fig.update_traces(marker_size=3)
fig.update_layout(height=400, width=700, font=dict(size=11))
fig.show()
# Out:
# <div>                            <div id="336e2917-7135-41a2-8220-af119aa71b96" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("336e2917-7135-41a2-8220-af119aa71b96")) {                    Plotly.newPlot(                        "336e2917-7135-41a2-8220-af119aa71b96",                        [{"hovertemplate":"auto_ownership_2=0<br>acs data=%{x}<br>model results=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle","size":3},"mode":"markers","name":"","showlegend":false,"x":[18.081180811808117,18.181818181818183,18.170580964153277,18.206278026905828,18.093699515347335,6.292134831460674,6.172839506172839,6.292134831460674,6.216696269982238,6.301369863013699,6.25,6.118546845124283,6.109324758842444,25.75835475578406,25.869262865090402,25.720384204909283,18.317757009345794,18.313253012048193,18.076285240464344,18.226002430133658,1.937984496124031,1.9337016574585635,2.0361990950226243,8.81294964028777,8.814102564102564,8.734939759036145,8.827586206896552,8.709677419354838,8.848080133555927,12.251941328731665,12.162162162162161,12.171837708830548,12.280701754385966,1.6842105263157894,1.9031141868512111,2.3706896551724137,2.4630541871921183,5.277044854881266,4.926108374384237,6.509945750452079,6.410256410256411,21.26865671641791,21.296296296296298,21.220723917672107,21.221374045801525,21.25,13.583138173302109,13.612565445026178,13.607188703465981,7.751937984496124,7.581227436823105,7.6923076923076925,7.73286467486819,3.5714285714285716,3.6713286713286712,4.585537918871252,4.6263345195729535,4.704301075268817,18.418079096045197,18.403908794788272,18.315018315018314,13.836477987421384,13.84297520661157,13.855421686746988,13.612565445026178,5.327245053272451,5.180722891566265,5.2439024390243905,12.997658079625293,12.947189097103918,13.102119460500964,8.131067961165048,7.982261640798226,8.108108108108109,3.8461538461538463,3.7914691943127963,3.9244186046511627,4.355108877721943,4.370629370629371,4.120443740095087,4.08997955010225,2.763819095477387,2.7848101265822787,2.6970954356846475,6.6115702479338845,6.5349544072948325,6.11353711790393,6.214689265536723,6.175771971496437,6.265664160401003,2.2257551669316373,2.3465703971119134,2.1782178217821784,2.304147465437788,7.885304659498208,8.045977011494253,7.9245283018867925,7.861635220125786,5.007153075822604,5.007824726134586,5.040650406504065,2.8368794326241136,2.848575712143928,2.9535864978902953,2.8776978417266186,3.476482617586912,3.522504892367906,3.5587188612099645,3.5335689045936394,3.5398230088495577,11.041666666666666,11.006711409395972,11.052166224580018,10.943912448700411,11.075949367088608,11.02661596958175,10.944206008583691,7.6923076923076925,7.763401109057301,7.769423558897243,7.741935483870968,7.829181494661921,5.166051660516605,5.009633911368016,5.208333333333333,10.714285714285714,10.703363914373089,10.606060606060606,15.46644844517185,15.491803278688524,15.492957746478874,15.52,7.957957957957958,7.94044665012407,6.901217861975643,6.651376146788991,10.194174757281553,10.303030303030303,2.7656477438136826,2.735562310030395,2.766798418972332,2.610441767068273,2.816901408450704,2.7439024390243905,3.5190615835777126,3.5114503816793894,3.498542274052478,3.5058430717863107,3.4111310592459607,13.278008298755188,13.333333333333334,13.406593406593407,48.33997343957503,48.405466970387245,30.87649402390438,30.794341675734493,30.72289156626506,30.837359098228664,10.53864168618267,10.476190476190476,2.484472049689441,2.6101141924959217,2.5280898876404496,16.844919786096256,16.813048933500628,16.852589641434264,16.877637130801688,4.536082474226804,4.7913446676970635,4.741379310344827,4.690431519699812,12.948517940717629,12.934631432545201,12.914691943127963,12.837837837837839,12.884834663625998,13.35149863760218,13.27102803 ...
