# %% [raw]
# ---
# title: Trip Mode Choice
# date: today
# ---

# %% [markdown]
# The trip mode choice models explanatory variables include household and person variables, level-of-service between the trip origin and destination according to the time period for the tour leg, urban form variables, and alternative-specific constants segmented by tour mode.

# %%
import os
import toml
import pandas as pd
import numpy as np
import plotly.express as px
import validation_data_input
import psrc_theme


import plotly.io as pio
pio.renderers.default = "plotly_mimetype+notebook_connected" # to show plotly figures in quarto HTML file
pio.templates.default = "simple_white+psrc_color" # set plotly template

config = toml.load(os.path.join(os.getcwd(), 'validation_configuration.toml'))

# %%
# %store -r validation_data

# read data
land_use = validation_data.land_use[['zone_id','log_emptot_1','log_hh_1']].copy()
# we want uncloned data (multiple days)
hh_data = validation_data.hh_data.copy()
per_data = validation_data.persons_data.copy()
tour_data = validation_data.tours.copy()
trip_data = validation_data.trips.copy()

del validation_data

# %%
# add auto_ownership with 4+
hh_data['auto_ownership_simple'] = hh_data['auto_ownership'].apply(lambda x: "4+" if x>=4.0 else str(x))
# household density groups
var_group = land_use['log_hh_1'].quantile([.00, .125, .25, .50, .75,1.00])
land_use['household_density_bin'] = pd.cut(land_use['log_hh_1'], bins=var_group.tolist(),
                                           labels=['very low', 'low', 'medium', 'medium-high', 'high'])

# add person type labels
ptype_cat = {1: "1: Full-Time Worker",
             2: "2: Part-Time Worker",
             3: "3: University Student",
             4: "4: Non-Working Adult Age <65",
             5: "5: Non-Working Adult Age 65+",
             6: "6: High School Student Age 16+",
             7: "7: Child Age 5-15",
             8: "8: Child Age 0-4"}
per_data['ptype_label'] = per_data['ptype'].map(ptype_cat)

hh_data = hh_data.merge(land_use[['log_hh_1','household_density_bin','zone_id']],how="left",left_on='home_zone_id',right_on='zone_id')
per_data = per_data.merge(hh_data[['household_id','auto_ownership','auto_ownership_simple','log_hh_1','household_density_bin','source']],
                          how='left', on=['household_id','source']) # get auto ownership from hh data

trip_data = trip_data.merge(per_data, how = 'left', on=['person_id', 'source'])

#tour_data = tour_data.merge(per_data, how='left', on=['person_id','household_id','source'])

# trip_data = trip_data.merge(tour_data, how='left',
#                              on=['person_id','household_id','tour_id','source'])

# trip_data = trip_data.merge(tour_data, how='left',
#                               on=['tour_id','source'])

# %%
len(trip_data[trip_data.person_id==0])
# Out:
# 5

# %%
trip_data.columns
# Out:
# Index(['trip_id', 'person_id', 'household_id_x', 'trip_mode', 'purpose',
#        'outbound', 'od_dist_drive', 'tour_id', 'trip_weight', 'source',
#        'trip_distance', 'home_zone_id', 'workplace_zone_id', 'ptype',
#        'pemploy', 'household_id_y', 'telecommute_frequency', 'work_from_home',
#        'is_worker', 'is_highschool', 'is_university', 'is_student',
#        'is_gradeschool', 'distance_to_work', 'free_parking_at_work',
#        'distance_to_school', 'cdap_activity', 'person_weight',
#        'person_id_elmer_original', 'ptype_label', 'auto_ownership',
#        'auto_ownership_simple', 'log_hh_1', 'household_density_bin'],
#       dtype='object')

# %% [markdown]
# - match values trip purpose and trip mode

# %%
#| echo: true
trip_data['purpose_match'] = trip_data['purpose'].apply(lambda x: "home" if x == "Home" else x)
trip_data['trip_mode_match'] = trip_data['trip_mode'].apply(lambda x: "TNC" if x == "TNC_SINGLE" else x)

# %%
# aggregate transit modes
transit_modes = ['WALK_LOC','WALK_COM','WALK_FRY','WALK_LR','DRIVE_TRN']
trip_mode_ordered = ["DRIVEALONEFREE", "SHARED2FREE", "SHARED3FREE", "BIKE","WALK","ALL_TRANSIT","SCH_BUS","TNC","Other"]
trip_data['trip_mode_transit_agg'] = trip_data['trip_mode_match'].apply(lambda x: "ALL_TRANSIT" if x in transit_modes else x)

df_plot = trip_data.groupby(['source','trip_mode_transit_agg'])['trip_weight'].sum().reset_index()
df_plot['percentage'] = df_plot.groupby(['source'], group_keys=False)['trip_weight']. \
    apply(lambda x: x / float(x.sum()))

fig = px.bar(df_plot, x="trip_mode_transit_agg", y="percentage", color="source",barmode="group",
             category_orders={"trip_mode_transit_agg": trip_mode_ordered},
             title="Trip mode choice: all modes")
fig.for_each_annotation(lambda a: a.update(text = a.text.split("=")[-1]))
fig.update_layout(height=400, width=700, yaxis=dict(tickformat=".1%"))
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="deb2ea9c-57db-4a19-834e-ce6d3df53f31" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("deb2ea9c-57db-4a19-834e-ce6d3df53f31")) {                    Plotly.newPlot(                        "deb2ea9c-57db-4a19-834e-ce6d3df53f31",                        [{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003etrip_mode_transit_agg=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":true,"textposition":"auto","x":["ALL_TRANSIT","BIKE","DRIVEALONEFREE","SCH_BUS","SHARED2FREE","SHARED3FREE","TNC","WALK"],"xaxis":"x","y":{"dtype":"f8","bdata":"WErVJ9eArj+yuqJ4+q5+P1lGOb6XbN0\u002fXtOH6LTcsT9TEdOw02PGPxJZDf1i2rI\u002f4j96csI5aT9Yems43GzDPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data\u003cbr\u003etrip_mode_transit_agg=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey data","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":true,"textposition":"auto","x":["ALL_TRANSIT","BIKE","DRIVEALONEFREE","Other","SCH_BUS","SHARED2FREE","SHARED3FREE","TNC","WALK"],"xaxis":"x","y":{"dtype":"f8","bdata":"V47+9+sNnD\u002f1wgagJwSGP5Znwfz+Gtw\u002fHfs53fK5jD+CmBEOOlGRP2hb2l3tQco\u002fNUB2z\u002fAgxj\u002f93t61E8FxPw0bz6WpArw\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=unweighted survey\u003cbr\u003etrip_mode_transit_agg=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"unweighted survey","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"unweighted survey","offsetgroup":"unweighted survey","orientation":"v","showlegend":true,"textposition":"auto","x":["ALL_TRANSIT","BIKE","DRIVEALONEFREE","Other","SCH_BUS","SHARED2FREE","SHARED3FREE","TNC","WALK"],"xaxis":"x","y":{"dtype":"f8","bdata":"TPFHsleuqD9M8UeyV66YP6RwPQrXo9g\u002fzYaLPcSVlD931b1DooqAPw65NLwAFsc\u002fUyrOPnyGvT+tYbTflOdyP8ZkI9oSa8s\u002f"},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale ...

# %%
# show only transit modes
df_plot = trip_data.groupby(['source','trip_mode_match'])['trip_weight'].sum().reset_index()
df_plot['percentage'] = df_plot.groupby(['source'], group_keys=False)['trip_weight']. \
    apply(lambda x: x / float(x.sum()))

fig = px.bar(df_plot.loc[df_plot['trip_mode_match'].isin(transit_modes)], x="trip_mode_match", y="percentage", color="source",barmode="group",
             title="Trip mode choice: transit modes")
fig.for_each_annotation(lambda a: a.update(text = a.text.split("=")[-1]))
fig.update_layout(height=400, width=700, yaxis=dict(tickformat=".1%"))
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="4561baa6-eeda-4da1-bdae-96efeffcea09" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("4561baa6-eeda-4da1-bdae-96efeffcea09")) {                    Plotly.newPlot(                        "4561baa6-eeda-4da1-bdae-96efeffcea09",                        [{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003etrip_mode_match=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":true,"textposition":"auto","x":["DRIVE_TRN","WALK_LOC","WALK_LR"],"xaxis":"x","y":{"dtype":"f8","bdata":"FEarUr59dz9+dkhOJVarPyCMtZsHfT0\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data\u003cbr\u003etrip_mode_match=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey data","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":true,"textposition":"auto","x":["DRIVE_TRN","WALK_COM","WALK_FRY","WALK_LOC","WALK_LR"],"xaxis":"x","y":{"dtype":"f8","bdata":"QMIb4n13VT+2T4cRlqNHP5u7dMGqS0s\u002fh8AkJ4HGmD9GVAwIOx42Pw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=unweighted survey\u003cbr\u003etrip_mode_match=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"unweighted survey","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"unweighted survey","offsetgroup":"unweighted survey","orientation":"v","showlegend":true,"textposition":"auto","x":["DRIVE_TRN","WALK_COM","WALK_FRY","WALK_LOC","WALK_LR"],"xaxis":"x","y":{"dtype":"f8","bdata":"eOoNRbfaYT\u002f1Kiq3IFNDP0ecIJlUPz4\u002fGy\u002fdJAaBpT9Wmq\u002fQrl1oPw=="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcont ...

# %% [markdown]
# ## Trip mode choice by segment

# %%
def plot_mode_choice(df: pd.DataFrame, grp_var: str, n_nol: int, height: int):
    df_plot = df.groupby(['source',grp_var,'trip_mode_transit_agg'])['trip_weight'].sum().reset_index()
    df_plot['percentage'] = df_plot.groupby(['source',grp_var], group_keys=False)['trip_weight']. \
        apply(lambda x: x / float(x.sum()))

    fig = px.bar(df_plot,
                 x="percentage", y="trip_mode_transit_agg", color="source",barmode="group",
                 facet_col=grp_var, facet_col_wrap=n_nol, orientation='h',
                 category_orders={"trip_mode_transit_agg": trip_mode_ordered},
                 title="Trip mode choice by " + grp_var)
    fig.for_each_annotation(lambda a: a.update(text = a.text.split("=")[-1]))
    fig.update_layout(height=height, width=700, xaxis1=dict(tickformat=".0%"), xaxis2=dict(tickformat=".0%")
                      )
    fig.show()
def plot_mode_choice_transit(df: pd.DataFrame,  grp_var: str, n_nol: int, height: int):
    df_plot = df.groupby(['source',grp_var,'trip_mode_match'])['trip_weight'].sum().reset_index()
    df_plot['percentage'] = df_plot.groupby(['source',grp_var], group_keys=False)['trip_weight']. \
        apply(lambda x: x / float(x.sum()))

    fig = px.bar(df_plot.loc[df_plot['trip_mode_match'].isin(transit_modes)],
                 x="percentage", y="trip_mode_match", color="source",barmode="group",
                 facet_col=grp_var, facet_col_wrap=n_nol, orientation='h',
                 category_orders={grp_var: pd.Series(df_plot[grp_var].unique()).sort_values().to_list()},
                 title="Trip mode choice by " + grp_var + ": disaggregated transit modes")
    fig.for_each_annotation(lambda a: a.update(text = a.text.split("=")[-1]))
    fig.update_layout(height=height, width=700, xaxis1=dict(tickformat=".1%"), xaxis2=dict(tickformat=".1%")
                      )
    fig.show()

# %% [raw]
# ::: {.panel-tabset}
#
# ### trip purpose

# %%
plot_mode_choice(trip_data,'purpose_match',3,1200)
plot_mode_choice_transit(trip_data,'purpose_match',3,800)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="4919b6ea-c6ad-469e-81aa-48244531b634" class="plotly-graph-div" style="height:1200px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("4919b6ea-c6ad-469e-81aa-48244531b634")) {                    Plotly.newPlot(                        "4919b6ea-c6ad-469e-81aa-48244531b634",                        [{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003epurpose_match=atwork\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"Z0U\u002fQZZ+kD93C4u8Ei44P7j+TZhQYtk\u002f++iS5cwUtT8\u002foIDhUoWvP1Ofjb\u002fHNmk\u002fqQDbWW8n3D8="},"xaxis":"x10","y":["ALL_TRANSIT","BIKE","DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","TNC","WALK"],"yaxis":"y10","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003epurpose_match=eatout\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"5d7OGRSnpz+CGxXBRJ1rPyFh7YAdOdw\u002fMycRsnwUnz+A7uu0JuTKP8rsXetCY7g\u002fr\u002fdolARwaD\u002ftg34Rc9vFPw=="},"xaxis":"x11","y":["ALL_TRANSIT","BIKE","DRIVEALONEFREE","SCH_BUS","SHARED2FREE","SHARED3FREE","TNC","WALK"],"yaxis":"y11","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003epurpose_match=escort\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"8gnzSO7blz8j\u002fnmREUB+P4\u002fspJM+Ctg\u002ftodWP6t1pj\u002f994P7LuDTP8XYlPmSJ74\u002fFuG2SlaIVj9ME50lw76+Pw=="},"xaxis":"x12","y":["ALL_TRANSIT","BIKE","DRIVEALONEFREE","SCH_BUS","SHARED2FREE","SHARED3FREE","TNC","WALK"],"yaxis":"y12","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003epurpose_match=home\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"wDPyQ+RlsT8umejuiDmCP+e2cDPFO90\u002fw0zZ+r+2sz\u002fuDW4aZdDHP9XT\u002fjOZs7M\u002fWW6EN9i9aj+Vff2qw4K\u002fPw=="},"xaxis":"x7","y":["ALL_TRANSIT","BIKE","DRIVEALONEFREE","SCH_BUS","SHARED2FREE","SHARED3FREE","TNC","WALK"],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003epurpose_match=othdiscr\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"H3XXcVrRqD+rCgvFyB59P6F\u002f6Pejlto\u002fD3v3oJPepT81NolLsa7JP\u002fULpK+BYbk\u002ftele2aDhbD+HNJKezWrHPw=="},"xaxis":"x8","y":["ALL_TRANSIT","BIKE","DRIVEALONEFREE","SCH_BUS","SHARED2FREE","SHARED3FREE","TNC","WALK"],"yaxis":"y8","type":"bar"},{"a ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="e7c691ac-53e5-4a3b-8cb0-879e68d00f18" class="plotly-graph-div" style="height:800px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e7c691ac-53e5-4a3b-8cb0-879e68d00f18")) {                    Plotly.newPlot(                        "e7c691ac-53e5-4a3b-8cb0-879e68d00f18",                        [{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003epurpose_match=atwork\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_match=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"OjQsCKiOjz8uaSWlR+hGPw=="},"xaxis":"x10","y":["WALK_LOC","WALK_LR"],"yaxis":"y10","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data\u003cbr\u003epurpose_match=atwork\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_match=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey data","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"n7OwRsTBbj\u002fZDv1Q6oSDP04hW3MyYkY\u002f"},"xaxis":"x10","y":["DRIVE_TRN","WALK_FRY","WALK_LOC"],"yaxis":"y10","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=unweighted survey\u003cbr\u003epurpose_match=atwork\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_match=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"unweighted survey","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"unweighted survey","offsetgroup":"unweighted survey","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"IwfCgvnDVD8jB8KC+cNUP7UKI0T2JX8\u002f"},"xaxis":"x10","y":["DRIVE_TRN","WALK_FRY","WALK_LOC"],"yaxis":"y10","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data\u003cbr\u003epurpose_match=change_mode\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_match=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey data","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"14g\u002flXTxlT82UCruNHvWP2Y\u002fSNa9UTQ\u002f"},"xaxis":"x11","y":["DRIVE_TRN","WALK_LOC","WALK_LR"],"yaxis":"y11","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=unweighted survey\u003cbr\u003epurpose_match=change_mode\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_match=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"unweighted survey","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"unweighted survey","offsetgroup":"unweighted survey","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"7RvWvmHtqz9GF1100UXXP54S5ClBnqI\u002f"},"xaxis":"x11","y":["DRIVE_TRN","WALK_LOC","WALK_LR"],"yaxis":"y11","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003epurpose_match=eatout\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_match=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"+0YYewRwfT+FP1eEhJyjP1WgJYXBI0c\u002f"},"xaxis":"x12","y":["DRIVE_TRN","WALK_LOC","WALK_LR"],"yaxis":"y12","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data\u003cbr\u003epurpose_match=eatout\u003 ...

# %% [raw]
# ### person type

# %%
plot_mode_choice(trip_data,'ptype_label',2,1200)
plot_mode_choice_transit(trip_data,'ptype_label',3,800)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="d0e89691-f08e-4be6-b8e9-e688f1a2095b" class="plotly-graph-div" style="height:1200px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d0e89691-f08e-4be6-b8e9-e688f1a2095b")) {                    Plotly.newPlot(                        "d0e89691-f08e-4be6-b8e9-e688f1a2095b",                        [{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003eptype_label=1: Full-Time Worker\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"nODf7D97sz+1X4Zj6RRzP4w0KPFXy+E\u002f\u002fn9aqoTtwD+vWswLdgCuP\u002f\u002fVHyy4V2w\u002fhPTU61edxT8="},"xaxis":"x7","y":["ALL_TRANSIT","BIKE","DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","TNC","WALK"],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003eptype_label=2: Part-Time Worker\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"jsW\u002feHYDrj8nl4hG6xJzP7j6HuyJ6OA\u002fIjyP47vfyD88Lu8BWGazP3Q9TQTHg2I\u002fztaHVmxnwT8="},"xaxis":"x8","y":["ALL_TRANSIT","BIKE","DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","TNC","WALK"],"yaxis":"y8","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003eptype_label=3: University Student\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"7fj5fkzrwz8RizaEHkiKP2BnsxeWKd0\u002fHig0wKfIwz+DTwt0m+irP9IJLlFEXmQ\u002fexvgur0IxT8="},"xaxis":"x5","y":["ALL_TRANSIT","BIKE","DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","TNC","WALK"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003eptype_label=4: Non-Working Adult Age \u003c65\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"gyTQ91+MoT+VR7coK+1xP5wDAcqGat8\u002fxe3O+bN+zj\u002fT51SCk3i4P\u002fLhdsbaelo\u002f+OU9pH1IwT8="},"xaxis":"x6","y":["ALL_TRANSIT","BIKE","DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","TNC","WALK"],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003eptype_label=5: Non-Working Adult Age 65+\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"50ViMUCRpD8rfff7yABrP3phk8499eI\u002f\u002fuomYFsxxD9c2+W27tevP78KzzojoF0\u002fwAoUQR44wj8="},"xaxis":"x3","y":["ALL_TRANSIT","BIKE","DRIVEALONEFREE","SHARED2FREE","SHARED3FREE","TNC","WALK"],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"sourc ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="597d8cbe-5779-4458-a5b1-ae8bfbe76cfd" class="plotly-graph-div" style="height:800px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("597d8cbe-5779-4458-a5b1-ae8bfbe76cfd")) {                    Plotly.newPlot(                        "597d8cbe-5779-4458-a5b1-ae8bfbe76cfd",                        [{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003eptype_label=1: Full-Time Worker\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_match=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"ODzcMJFvgD\u002fCAkssQz2xP7MpqzxNBUg\u002f"},"xaxis":"x7","y":["DRIVE_TRN","WALK_LOC","WALK_LR"],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data\u003cbr\u003eptype_label=1: Full-Time Worker\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_match=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey data","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"154XKwUVVj\u002flkIsL7bQ+P\u002fJ1uY5uYEE\u002fhe8qCd4qjj8tFW8e\u002f90yPw=="},"xaxis":"x7","y":["DRIVE_TRN","WALK_COM","WALK_FRY","WALK_LOC","WALK_LR"],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=unweighted survey\u003cbr\u003eptype_label=1: Full-Time Worker\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_match=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"unweighted survey","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"unweighted survey","offsetgroup":"unweighted survey","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"AStqFDMoZD8wCCrUhqdJP7x0\u002f\u002f5O\u002fUU\u002fZLeH7EfwqD9H4dQpF1NyPw=="},"xaxis":"x7","y":["DRIVE_TRN","WALK_COM","WALK_FRY","WALK_LOC","WALK_LR"],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003eptype_label=2: Part-Time Worker\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_match=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"MELUJRVPeD\u002fucxN\u002fNcCqP+es5Hgqrzw\u002f"},"xaxis":"x8","y":["DRIVE_TRN","WALK_LOC","WALK_LR"],"yaxis":"y8","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data\u003cbr\u003eptype_label=2: Part-Time Worker\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_match=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey data","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"mu02QoZmWD8AAAAAAAAAAOpTiL7xMQk\u002fkItbZyIykz+\u002fyEo+fN9DPw=="},"xaxis":"x8","y":["DRIVE_TRN","WALK_COM","WALK_FRY","WALK_LOC","WALK_LR"],"yaxis":"y8","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=unweighted survey\u003cbr\u003eptype_label=2: Part-Time Worker\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_match=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"unweighted survey","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"unweighted survey","offsetgroup":"unweighted survey","orientation":"h","showlegend":false,"textposition":"auto","x":{ ...

# %% [raw]
# ### household density

# %%
plot_mode_choice(trip_data,'household_density_bin',3,600)
plot_mode_choice_transit(trip_data,'household_density_bin',3,500)
# Out:
# C:\Users\Modeller\AppData\Local\Temp\ipykernel_15392\3326892120.py:2: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# C:\Users\Modeller\AppData\Local\Temp\ipykernel_15392\3326892120.py:3: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="07d7ab90-4830-486e-8226-5591778f628f" class="plotly-graph-div" style="height:600px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("07d7ab90-4830-486e-8226-5591778f628f")) {                    Plotly.newPlot(                        "07d7ab90-4830-486e-8226-5591778f628f",                        [{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003ehousehold_density_bin=very low\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"rhvZzOpAij91gXoaVMtcP8qjQ21CmeE\u002fAAAAAAAAAAD4\u002fudHiG60PyTe2Damvck\u002f2z8VSuLWtT\u002fFZ6jCK1xXP3g3JD16XLE\u002f"},"xaxis":"x4","y":["ALL_TRANSIT","BIKE","DRIVEALONEFREE","Other","SCH_BUS","SHARED2FREE","SHARED3FREE","TNC","WALK"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003ehousehold_density_bin=low\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"dogEAm\u002fPkz\u002fO27efmERoPyQuYH+1yuA\u002fAAAAAAAAAAD\u002f7b7YU4m0P2k\u002fWHeVvMk\u002f0j9F6FDntT8R+APapJRiP37h+qjedbU\u002f"},"xaxis":"x5","y":["ALL_TRANSIT","BIKE","DRIVEALONEFREE","Other","SCH_BUS","SHARED2FREE","SHARED3FREE","TNC","WALK"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003ehousehold_density_bin=medium\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"yb8UTvzSoj8BzUo3HE91PwAsXsmBLd8\u002fAAAAAAAAAABRxk+nwH60P7XZDSL0rsg\u002fpJiGqDv2tD92u7LhydtkPw+bCA3GEb0\u002f"},"xaxis":"x6","y":["ALL_TRANSIT","BIKE","DRIVEALONEFREE","Other","SCH_BUS","SHARED2FREE","SHARED3FREE","TNC","WALK"],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003ehousehold_density_bin=medium-high\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"RmgsWqYCrT\u002f5IxDtlaR9P7Ds1vV46t0\u002fAAAAAAAAAAD77jiUcWeyPze3Vawt08Y\u002fR3bMQvUxsz9LLN6ZHw1nP+WoHjgqAcI\u002f"},"xaxis":"x","y":["ALL_TRANSIT","BIKE","DRIVEALONEFREE","Other","SCH_BUS","SHARED2FREE","SHARED3FREE","TNC","WALK"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003ehousehold_density_bin=high\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"Uz5Woa3YvD\u002fwTb28m9+KP8sFCrLxU9g\u002fAAAAAAAAAADVU7M\u002fKmapP\u002fZDscu3XsE\u002fwjQzmAClrD9WsoyqC6lyP7O0dTABx88\u002f"}," ...
# C:\Users\Modeller\AppData\Local\Temp\ipykernel_15392\3326892120.py:16: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# C:\Users\Modeller\AppData\Local\Temp\ipykernel_15392\3326892120.py:17: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="5394f0da-8b18-434a-91cd-52e3de4bca87" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("5394f0da-8b18-434a-91cd-52e3de4bca87")) {                    Plotly.newPlot(                        "5394f0da-8b18-434a-91cd-52e3de4bca87",                        [{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003ehousehold_density_bin=very low\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_match=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"SwG1UBO0gz8AAAAAAAAAAAAAAAAAAAAAFKFtfyr9aT+bPWSRuBn7Pg=="},"xaxis":"x4","y":["DRIVE_TRN","WALK_COM","WALK_FRY","WALK_LOC","WALK_LR"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data\u003cbr\u003ehousehold_density_bin=very low\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_match=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey data","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"fDvDkEUXSD8AAAAAAAAAAAAAAAAAAAAATXIh6BnoUD8AAAAAAAAAAA=="},"xaxis":"x4","y":["DRIVE_TRN","WALK_COM","WALK_FRY","WALK_LOC","WALK_LR"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=unweighted survey\u003cbr\u003ehousehold_density_bin=very low\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_match=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"unweighted survey","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"unweighted survey","offsetgroup":"unweighted survey","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"1aCh4FFEdT+qgLSzdANRPwAAAAAAAAAAqoC0s3QDgT8AAAAAAAAAAA=="},"xaxis":"x4","y":["DRIVE_TRN","WALK_COM","WALK_FRY","WALK_LOC","WALK_LR"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003ehousehold_density_bin=low\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_match=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"hwpcWkCygT8AAAAAAAAAAAAAAAAAAAAAFewNpGrXhT9UUBqfBTMFPw=="},"xaxis":"x5","y":["DRIVE_TRN","WALK_COM","WALK_FRY","WALK_LOC","WALK_LR"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data\u003cbr\u003ehousehold_density_bin=low\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_match=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey data","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"IueYV6LEHj8AAAAAAAAAAKRoSS06Nis\u002fHq4gWG38cD9\u002fUfHgwBUYPw=="},"xaxis":"x5","y":["DRIVE_TRN","WALK_COM","WALK_FRY","WALK_LOC","WALK_LR"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=unweighted survey\u003cbr\u003ehousehold_density_bin=low\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_match=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"unweighted survey","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"unweighted survey","offsetgroup":"unweighted survey","orientation":"h","showlegend":false,"textposition":"auto" ...

# %% [raw]
# ### auto ownership

# %%
plot_mode_choice(trip_data,'auto_ownership_simple',3,600)
plot_mode_choice_transit(trip_data,'auto_ownership_simple',3,500)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="ceaab7a4-86eb-4a87-be69-0a0810ae4909" class="plotly-graph-div" style="height:600px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("ceaab7a4-86eb-4a87-be69-0a0810ae4909")) {                    Plotly.newPlot(                        "ceaab7a4-86eb-4a87-be69-0a0810ae4909",                        [{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003eauto_ownership_simple=0\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"d2JtkZZk1z+cJQStX8GZP6SBTF+av6w\u002fQHK3lv8Doj\u002foup\u002fSY26pP9Z7aJaCUZk\u002fVg4RE+PDjT8m1a543HXbPw=="},"xaxis":"x4","y":["ALL_TRANSIT","BIKE","DRIVEALONEFREE","SCH_BUS","SHARED2FREE","SHARED3FREE","TNC","WALK"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003eauto_ownership_simple=1\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"n\u002fEVybXtsj9WYJKuiQaEP3zmR04EHN0\u002fgthHL1sfrT905SBl+nbCP681iochta0\u002ftYkPu2dDZD8MbTqyjJPJPw=="},"xaxis":"x5","y":["ALL_TRANSIT","BIKE","DRIVEALONEFREE","SCH_BUS","SHARED2FREE","SHARED3FREE","TNC","WALK"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003eauto_ownership_simple=2\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"h4\u002fudHbmpz9JhaWv+B98P6YnwD1YuN0\u002fojU1Ta9esz+1RG9TrvHHPy8vc2eXPrQ\u002fcXMtnFKYZz+9s5Ip\u002f5XBPw=="},"xaxis":"x6","y":["ALL_TRANSIT","BIKE","DRIVEALONEFREE","SCH_BUS","SHARED2FREE","SHARED3FREE","TNC","WALK"],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003eauto_ownership_simple=3\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"MnCpuRrwoj+ha3XMUYpzP9MkH+wg0N8\u002fPsJme6w2sz+RCo6IztjIP4G9SKJ9NrU\u002fqK9HzkOuZz+Ci6mIkDK7Pw=="},"xaxis":"x","y":["ALL_TRANSIT","BIKE","DRIVEALONEFREE","SCH_BUS","SHARED2FREE","SHARED3FREE","TNC","WALK"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003eauto_ownership_simple=4+\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_transit_agg=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"b9efBE5qoT\u002fLhB9MsghyPzjbA65vB+A\u002fThY2RUdisz9r\u002f8bykmDJP0fnZetv8rU\u002fYsNq5kjwYz+573ELcTm5Pw=="},"xaxis":"x2","y":["ALL_TRANSIT","BIKE","DRIVEALONEFREE","SCH_BUS","SHARED2FREE","SHARED3FREE","TNC","WALK"],"yaxis":"y2","type":"bar"},{"al ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="d37510cd-a2e0-44c6-be91-3033ee8817e4" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d37510cd-a2e0-44c6-be91-3033ee8817e4")) {                    Plotly.newPlot(                        "d37510cd-a2e0-44c6-be91-3033ee8817e4",                        [{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003eauto_ownership_simple=0\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_match=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"dPkUNGkP1z+XQBpWV0t1Pw=="},"xaxis":"x4","y":["WALK_LOC","WALK_LR"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data\u003cbr\u003eauto_ownership_simple=0\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_match=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey data","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"A8gGwHLjfz8X1L3mupj8PrbI6lx\u002fNZA\u002f3MXYNzxwyz\u002fUqUaFqmBVPw=="},"xaxis":"x4","y":["DRIVE_TRN","WALK_COM","WALK_FRY","WALK_LOC","WALK_LR"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=unweighted survey\u003cbr\u003eauto_ownership_simple=0\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_match=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"unweighted survey","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"unweighted survey","offsetgroup":"unweighted survey","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"gKeoZ5H0gD\u002fJ0l9mS41UP4uWDK6NqUg\u002fXm81YPsDyT8DLwL3FS2JPw=="},"xaxis":"x4","y":["DRIVE_TRN","WALK_COM","WALK_FRY","WALK_LOC","WALK_LR"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003eauto_ownership_simple=1\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_match=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"FaAM98BZdT8o3aQ7yXexP+A6JQA\u002fKEA\u002f"},"xaxis":"x5","y":["DRIVE_TRN","WALK_LOC","WALK_LR"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data\u003cbr\u003eauto_ownership_simple=1\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_match=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey data","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"rVNTbcaUYD8Bg+lwsathP2L\u002fQ0xG8kk\u002fiRlqDDrfpD+bT6HO0a5MPw=="},"xaxis":"x5","y":["DRIVE_TRN","WALK_COM","WALK_FRY","WALK_LOC","WALK_LR"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=unweighted survey\u003cbr\u003eauto_ownership_simple=1\u003cbr\u003epercentage=%{x}\u003cbr\u003etrip_mode_match=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"unweighted survey","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"unweighted survey","offsetgroup":"unweighted survey","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"XovRZN61WD\u002fQusEU+axLP417gX\u002fVuCc\u002f3rUYTeZdoz8umyFK57JpPw=="},"x ...

# %% [raw]
# :::
