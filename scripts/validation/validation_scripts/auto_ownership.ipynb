# %% [raw]
# ---
# title: Auto Ownership
# date: today
# ---

# %%
import os
import toml
import pandas as pd
import numpy as np
import validation_data_input
import plotly.express as px
import psrc_theme

# to show plotly figures in quarto HTML file
import plotly.io as pio

# %store -r validation_data

pio.renderers.default = "plotly_mimetype+notebook_connected"
pio.templates.default = "simple_white+psrc_color"

# auto ownership
#config = toml.load(os.path.join(os.getcwd(), 'validation_configuration.toml'))
config = toml.load(os.path.join(os.getcwd(), 'validation_configuration.toml'))

# %% [markdown]
# ## Household data
#
# - income, hh density, employment density grouped into very low, low, medium, medium-high and high

# %%
# read data
#land_use = pd.read_csv(config['p_survey_landuse'], usecols=['zone_id','log_emptot_1','log_hh_1'])
land_use = validation_data.land_use[['zone_id','log_emptot_1','log_hh_1']].copy()

# hh_data = validation_data_input.get_households_data(['home_zone_id','auto_ownership','hhsize','num_workers','num_adults','num_drivers','income'])
hh_data = validation_data.hh_data_uncloned.copy()
# delete shared data
del validation_data

hh_data = hh_data.merge(land_use,how="left",left_on='home_zone_id',right_on='zone_id').\
    merge(pd.read_csv(config['p_maz_bg_lookup'])[['MAZ', 'block_group_id']], how="left",left_on='home_zone_id',right_on='MAZ')

# %%
# grouping income, hh density, employment density into very low, low, medium, medium-high and high
var_group = hh_data.loc[hh_data['source']=="model results", ['income','log_emptot_1','log_hh_1']].quantile([.125, .25, .50, .75])
var_group
# Out:
#          income  log_emptot_1  log_hh_1
# 0.125   24000.0      1.321043  4.434358
# 0.250   43000.0      2.922615  5.089858
# 0.500   82000.0      4.726863  5.721498
# 0.750  135000.0      6.239594  6.457123

# %%
income_4group = hh_data.loc[hh_data['source'] == 'model results',['income']].quantile([.25, .50, .75])
income_4group
# Out:
#         income
# 0.25   43000.0
# 0.50   82000.0
# 0.75  135000.0

# %%
# data manipulation

# add income group
hh_data['hhincome_group'] = pd.cut(hh_data['income'],bins=[-9999999.0] + income_4group['income'].tolist() + [9999999.0], labels=['low', 'medium', 'medium-high', 'high'])
# add hh density groups
hh_data['hh_density_group'] = pd.cut(hh_data['log_hh_1'],bins=[-9999999.0] + var_group['log_hh_1'].tolist() + [9999999.0], labels=['very low', 'low', 'medium', 'medium-high', 'high'])
# add employment density groups
hh_data['emp_density_group'] = pd.cut(hh_data['log_emptot_1'],bins=[-9999999.0] + var_group['log_emptot_1'].tolist() + [9999999.0], labels=['very low', 'low', 'medium', 'medium-high', 'high'])

# add auto_ownership with 4+
hh_data['auto_ownership_simple'] = np.where(hh_data['auto_ownership']>=4, "4+", hh_data['auto_ownership'])
# add auto_ownership with 2+
hh_data['auto_ownership_2'] = np.where(hh_data['auto_ownership']<2, hh_data['auto_ownership'], "2+")
# add hhsize with 4+
hh_data['hhsize_simple'] = np.where(hh_data['hhsize']>=4, "4+", hh_data['hhsize'])
# add num_workers with 4+
hh_data['num_workers_simple'] = np.where(hh_data['num_workers']>=4, "4+", hh_data['num_workers'])
# add num_adults with 4+
hh_data['num_adults_simple'] = np.where(hh_data['num_adults']>=4, "4+",hh_data['num_adults'])
# add num_drivers with 4+
hh_data['num_drivers_simple'] = np.where(hh_data['num_drivers']>=4, "4+",hh_data['num_drivers'])

# %% [markdown]
# ## Auto ownership across all households

# %%
df_plot = hh_data.groupby(['source','auto_ownership_simple'])['hh_weight'].sum().reset_index()

df_plot['percentage'] = df_plot.groupby(['source'], group_keys=False)['hh_weight'].\
        apply(lambda x: 100 * x / float(x.sum()))
df_plot['source'] = df_plot['source'].astype(pd.CategoricalDtype(['model results', 'survey data', 'unweighted survey']))

fig = px.bar(df_plot.sort_values(by=['source']), x="auto_ownership_simple", y="percentage", color="source",
             barmode="group",
             title="Auto ownership")
fig.update_layout(height=400, width=700, font=dict(size=11))
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="510dab15-f4ab-4acf-99e3-037855701bec" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("510dab15-f4ab-4acf-99e3-037855701bec")) {                    Plotly.newPlot(                        "510dab15-f4ab-4acf-99e3-037855701bec",                        [{"alignmentgroup":"True","hovertemplate":"source=model results<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[6.807295751537287,34.97377065315777,34.36919682319969,16.307608161404083,7.542128610701175],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[10.028946661008444,30.28058111618429,36.249952332246416,15.35237480684168,8.08814508371918],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=unweighted survey<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"unweighted survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"unweighted survey","offsetgroup":"unweighted survey","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[16.143130292269873,44.3048347446053,28.87189292543021,7.402349084949467,3.2777929527451515],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.66 ...

# %% [markdown]
# ## Auto ownership by segments

# %%
# auto ownership in Income groups
def plot_auto(df:pd.DataFrame, var:str, title_cat:str,sub_name:str):
    print(f"n=\n"
          f"{df.loc[df['source']=='model results',var].value_counts()[df[var].sort_values().unique()]}")
    df_plot = df.groupby(['source',var,'auto_ownership_simple'])['hh_weight'].sum().reset_index()
    df_plot['percentage'] = df_plot.groupby(['source',var], group_keys=False)['hh_weight'].\
        apply(lambda x: 100 * x / float(x.sum()))

    fig = px.bar(df_plot, x="auto_ownership_simple", y="percentage", color="source",
                 facet_col=var, barmode="group",
                 title="Auto ownership by "+ title_cat)
    fig.for_each_annotation(lambda a: a.update(text = sub_name + "=<br>" + a.text.split("=")[-1]))
    fig.update_xaxes(title_text="n of cars")
    fig.update_layout(height=400, width=800, font=dict(size=11))
    fig.show()

# %% [raw]
# ::: {.panel-tabset}

# %% [raw]
# ### Income

# %%
plot_auto(hh_data,'hhincome_group','income level', 'Income')
# Out:
# n=
# low            401452
# medium         402805
# medium-high    404394
# high           396612
# Name: hhincome_group, dtype: int64
# <div>                            <div id="09105b60-127a-4e0c-88e4-f9933dd15b81" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("09105b60-127a-4e0c-88e4-f9933dd15b81")) {                    Plotly.newPlot(                        "09105b60-127a-4e0c-88e4-f9933dd15b81",                        [{"alignmentgroup":"True","hovertemplate":"source=model results<br>hhincome_group=low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[16.408437372338412,56.76569054332772,20.434074310253777,4.691968155595189,1.6998296184848998],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>hhincome_group=medium<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[5.761348543339829,42.236069562195105,34.18279316294485,11.354873946450516,6.464914785069698],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>hhincome_group=medium-high<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[3.154596754650168,23.97241304272566,39.47462128518227,21.083893430664155,12.314475486777747],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>hhincome_group=high<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":[1.875636642360796,16.75743547850292,43.458090022490495,28.22506631165976,9.683771544986032],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>hhincome_group=low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[21.78170094588608,37.76590946214678,22.594869904400415,10.463526490436491,7.393993197130224],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>hhincome_group=medium<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[5.142605287751833,41.547159305975406,39.18784461220655,10.651429264452632,3.47096152961359],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>hhincome_group=medium-high<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[3.48931551016338,31.0549830160831 ...

# %% [raw]
# ### Household size

# %%
plot_auto(hh_data,'hhsize_simple','household size', 'HH size')
# Out:
# n=
# 1     452162
# 2     533682
# 3     254336
# 4+    365083
# Name: hhsize_simple, dtype: int64
# <div>                            <div id="4af9ed98-9f17-44f6-8f85-93a367d76234" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4af9ed98-9f17-44f6-8f85-93a367d76234")) {                    Plotly.newPlot(                        "4af9ed98-9f17-44f6-8f85-93a367d76234",                        [{"alignmentgroup":"True","hovertemplate":"source=model results<br>hhsize_simple=1<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[16.536772218806533,69.80573334335924,10.497786191674665,2.340532817883856,0.8191754282757064],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>hhsize_simple=2<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[4.328420295231992,27.632747591262213,50.32903489343841,14.23694259877605,3.4728546212913307],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>hhsize_simple=3<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[2.0107259687971815,18.321433064921994,38.29579768495219,31.035716532460995,10.33632674886764],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>hhsize_simple=4+<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":[1.722348068795315,14.165819827272154,37.86864904692906,26.37263307247941,19.870549984524068],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>hhsize_simple=1<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[26.222698228075313,61.03013582394065,8.387120952277732,2.5498781385890794,1.810166857117227],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>hhsize_simple=2<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[3.155963628669489,18.62827538434214,57.92236913723707,13.479332800483053,6.814059049268242],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>hhsize_simple=3<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[1.3725078284446453,11.104902984667484,44.05184163274986,34.78506846975466, ...

# %% [raw]
# ### Number of workers

# %%
plot_auto(hh_data,'num_workers_simple','number of workers','num workers')
# Out:
# n=
# 0     355309
# 1     637690
# 2     504466
# 3      99225
# 4+      8573
# Name: num_workers_simple, dtype: int64
# <div>                            <div id="21a827f0-bf4b-4c7f-8973-b0d9ab85d650" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("21a827f0-bf4b-4c7f-8973-b0d9ab85d650")) {                    Plotly.newPlot(                        "21a827f0-bf4b-4c7f-8973-b0d9ab85d650",                        [{"alignmentgroup":"True","hovertemplate":"source=model results<br>num_workers_simple=0<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[12.91382993394482,53.35834442696357,24.89072891483188,6.632255304537741,2.2048414197219883],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>num_workers_simple=1<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[7.936928601671658,44.33721714312597,31.37982405243927,11.531935579984005,4.814094622779093],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>num_workers_simple=2<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[2.1858757577319383,16.110699234438,46.530588781008035,24.506706101104932,10.666130125717094],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>num_workers_simple=3<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":[1.3343411438649533,7.5122197026958935,26.810783572688333,38.95389266817838,25.388762912572435],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>num_workers_simple=4+<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x5","y":[4.980753528519771,4.350869007348653,21.427738247987868,27.959874023095765,41.28076519304794],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>num_workers_simple=0<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[28.042812498272685,42.80111518405968,18.247501675565648,6.913391057645492,3.9951795844564884],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>num_workers_simple=1<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[10.484409111903751,45.082978088 ...

# %% [raw]
# ### Number of drivers

# %%
plot_auto(hh_data.loc[hh_data['num_drivers_simple']!="0"],'num_drivers_simple','number of drivers','num drivers')
# Out:
# n=
# 1     493312
# 2     708568
# 3     274525
# 4+    128847
# Name: num_drivers_simple, dtype: int64
# <div>                            <div id="c158d267-c6e1-4217-a04f-415f5a6efb91" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c158d267-c6e1-4217-a04f-415f5a6efb91")) {                    Plotly.newPlot(                        "c158d267-c6e1-4217-a04f-415f5a6efb91",                        [{"alignmentgroup":"True","hovertemplate":"source=model results<br>num_drivers_simple=1<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[15.951162752983914,70.18377821743643,10.711274001037882,2.339493059159315,0.8142919693824597],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>num_drivers_simple=2<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[3.386830904020503,24.490803987761232,54.369799369996954,14.30264985153154,3.4499158866897743],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>num_drivers_simple=3<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[1.163828430926145,11.703123577087696,32.33075311902377,40.63236499408068,14.169929878881705],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>num_drivers_simple=4+<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":[2.627146926199291,7.397145451582109,19.30429113599851,28.987093219089306,41.684323267130786],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>num_drivers_simple=1<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[25.913785788629923,60.96551542496018,8.777793165234078,2.5381558576515055,1.8047497635242984],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>num_drivers_simple=2<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[2.5068098085056403,16.723265276250896,60.09321978564413,15.029416648521012,5.64728848107832],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>num_drivers_simple=3<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[0.9105581260316811,8.41546445269251,3 ...

# %% [raw]
# ### Household density

# %%
plot_auto(hh_data.dropna(subset=['hh_density_group']),'hh_density_group','household density','density')
# Out:
# n=
# very low       200677
# low            200647
# medium         401318
# medium-high    401356
# high           401265
# Name: hh_density_group, dtype: int64
# <div>                            <div id="bc7117c9-cf27-48ce-83f4-0abfa1f18dd8" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bc7117c9-cf27-48ce-83f4-0abfa1f18dd8")) {                    Plotly.newPlot(                        "bc7117c9-cf27-48ce-83f4-0abfa1f18dd8",                        [{"alignmentgroup":"True","hovertemplate":"source=model results<br>hh_density_group=very low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.2606178087174913,13.594980989351047,37.34757844695705,31.999681079545738,16.797141675428673],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>hh_density_group=low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[0.9185285601080505,22.074588705537586,41.16333660607933,24.52765304240781,11.31589308586722],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>hh_density_group=medium<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[1.9981660428886818,29.62015160047643,40.007674711824535,19.485794307755945,8.888213337054406],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>hh_density_group=medium-high<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":[4.9860971307268365,42.315550284535426,34.92560220851314,12.306281705019982,5.466468671204616],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>hh_density_group=high<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x5","y":[19.657333682229947,50.126475022740586,23.286606108182873,5.173139944924177,1.7564452419224204],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>hh_density_group=very low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[2.182149343441709,21.477012884025235,34.46750408764483,22.51651675577328,19.35681692911495],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>hh_density_group=low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[4.2458 ...

# %% [raw]
# ### Employment density

# %%
plot_auto(hh_data.dropna(subset=['emp_density_group']),'emp_density_group','employment density','density')
# Out:
# n=
# very low       200684
# low            200685
# medium         401476
# medium-high    401132
# high           401286
# Name: emp_density_group, dtype: int64
# <div>                            <div id="743f0271-d9ff-4586-892d-d80413ce32dc" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("743f0271-d9ff-4586-892d-d80413ce32dc")) {                    Plotly.newPlot(                        "743f0271-d9ff-4586-892d-d80413ce32dc",                        [{"alignmentgroup":"True","hovertemplate":"source=model results<br>emp_density_group=very low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.22921608100296983,15.365948456279524,38.74200235195631,29.75324390584202,15.909589204919177],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>emp_density_group=low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[0.55210902658395,20.17240949747116,40.525201185938165,26.02536313127538,12.724917158731346],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>emp_density_group=medium<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[1.7478006157279637,29.964680329583835,39.98570275682731,19.464426267074494,8.837390030786398],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>emp_density_group=medium-high<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":[5.161143962585882,42.14946700836632,35.13681281972019,12.446027741491578,5.106548467836024],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>emp_density_group=high<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x5","y":[19.93266647727556,50.020434303713564,22.717214156486893,5.4253076359504195,1.904377426573566],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>emp_density_group=very low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[1.9169887259184333,12.914945492045263,45.397778987969374,21.974400676473024,17.795886117593902],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>emp_density_group=low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y": ...

# %% [raw]
# :::

# %% [markdown]
# ## Validate auto ownership with ACS vehicle ownership data
#
# - TO-DO:
#     1. get auto ownership values [0,1,2,3,4+] from ACS data.
#     2. check block_group_id values: not matching ACS block group IDs
#
# - household counts in ACS data

# %%
print(f"n=\n"
      f"{hh_data.loc[hh_data['source']=='model results','auto_ownership_2'].value_counts()[hh_data['auto_ownership_2'].sort_values().unique()]}")
      
df = hh_data.groupby(['source','block_group_id','auto_ownership_2'])['hh_weight'].sum().reset_index()
# df_plot = df_plot.loc[df_plot['auto_ownership_2']!="-1"]

df['percentage'] = df.groupby(['source','block_group_id'], group_keys=False)['hh_weight'].\
    apply(lambda x: 100 * x / float(x.sum()))

# acs auto ownership data
acs_auto_ownership = pd.read_csv(config['p_acs_auto_ownership'])[['cars_none_control', 'cars_one_control', 'cars_two_or_more_control', 'block_group_id']]

# calculate percentage of households having 0, 1 or 2+ vehicle(s) in each block group
acs_auto_ownership['total'] = acs_auto_ownership['cars_one_control'] + acs_auto_ownership['cars_two_or_more_control'] + acs_auto_ownership['cars_none_control']
acs_auto_ownership['0'] = 100 * acs_auto_ownership['cars_none_control']/acs_auto_ownership['total']
acs_auto_ownership['1'] = 100 * acs_auto_ownership['cars_one_control']/acs_auto_ownership['total']
acs_auto_ownership['2+'] = 100 * acs_auto_ownership['cars_two_or_more_control']/acs_auto_ownership['total']
acs_auto_ownership['source'] = "acs data"
bg_auto_ownership = acs_auto_ownership[['source','block_group_id','0','1','2+']]
bg_auto_ownership = pd.melt(bg_auto_ownership, id_vars=['source','block_group_id'], value_vars=['0','1','2+'], var_name='auto_ownership_2',value_name='percentage')

# combine both sets of data
col_list = ['source','block_group_id','auto_ownership_2','percentage']
bg_auto_ownership = pd.concat([df[col_list].copy(),
                               bg_auto_ownership[col_list].copy()])

# bg_auto_ownership
# Out:
# n=
# 0     109275
# 1     561421
# 2+    934567
# Name: auto_ownership_2, dtype: int64

# %% [markdown]
# - scatterplot

# %%
df_plot = pd.pivot(bg_auto_ownership, index=['block_group_id','auto_ownership_2'], columns='source', values='percentage').reset_index()



fig = px.scatter(df_plot, x="acs data", y="model results", trendline="ols", trendline_color_override='rgb(136, 136, 136)',
                 template="plotly_white",
                 facet_col='auto_ownership_2', height=400, width=1000,
                 title="Auto ownership model results validation with acs data")
fig.update_xaxes(dtick=20)
fig.update_yaxes(dtick=20,range=[0, 100])
fig.update_traces(marker_size=3)
fig.update_layout(height=360, width=800, font=dict(size=11))
fig.show()
# Out:
# <div>                            <div id="6a3c69c9-7ac5-495a-af62-8c6d081899d6" class="plotly-graph-div" style="height:360px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6a3c69c9-7ac5-495a-af62-8c6d081899d6")) {                    Plotly.newPlot(                        "6a3c69c9-7ac5-495a-af62-8c6d081899d6",                        [{"hovertemplate":"auto_ownership_2=0<br>acs data=%{x}<br>model results=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle","size":3},"mode":"markers","name":"","showlegend":false,"x":[18.081180811808117,18.181818181818183,18.170580964153277,18.206278026905828,18.093699515347335,6.292134831460674,6.172839506172839,6.292134831460674,6.216696269982238,6.301369863013699,6.25,6.118546845124283,6.109324758842444,25.75835475578406,25.869262865090402,25.720384204909283,18.317757009345794,18.313253012048193,18.076285240464344,18.226002430133658,1.937984496124031,1.9337016574585635,2.0361990950226243,8.81294964028777,8.814102564102564,8.734939759036145,8.827586206896552,8.709677419354838,8.848080133555927,12.251941328731665,12.162162162162161,12.171837708830548,12.280701754385966,1.6842105263157894,1.9031141868512111,2.3706896551724137,2.4630541871921183,5.277044854881266,4.926108374384237,6.509945750452079,6.410256410256411,21.26865671641791,21.296296296296298,21.220723917672107,21.221374045801525,21.25,13.583138173302109,13.612565445026178,13.607188703465981,7.751937984496124,7.581227436823105,7.6923076923076925,7.73286467486819,3.5714285714285716,3.6713286713286712,4.585537918871252,4.6263345195729535,4.704301075268817,18.418079096045197,18.403908794788272,18.315018315018314,13.836477987421384,13.84297520661157,13.855421686746988,13.612565445026178,5.327245053272451,5.180722891566265,5.2439024390243905,12.997658079625293,12.947189097103918,13.102119460500964,8.131067961165048,7.982261640798226,8.108108108108109,3.8461538461538463,3.7914691943127963,3.9244186046511627,4.355108877721943,4.370629370629371,4.120443740095087,4.08997955010225,2.763819095477387,2.7848101265822787,2.6970954356846475,6.6115702479338845,6.5349544072948325,6.11353711790393,6.214689265536723,6.175771971496437,6.265664160401003,2.2257551669316373,2.3465703971119134,2.1782178217821784,2.304147465437788,7.885304659498208,8.045977011494253,7.9245283018867925,7.861635220125786,5.007153075822604,5.007824726134586,5.040650406504065,2.8368794326241136,2.848575712143928,2.9535864978902953,2.8776978417266186,3.476482617586912,3.522504892367906,3.5587188612099645,3.5335689045936394,3.5398230088495577,11.041666666666666,11.006711409395972,11.052166224580018,10.943912448700411,11.075949367088608,11.02661596958175,10.944206008583691,7.6923076923076925,7.763401109057301,7.769423558897243,7.741935483870968,7.829181494661921,5.166051660516605,5.009633911368016,5.208333333333333,10.714285714285714,10.703363914373089,10.606060606060606,15.46644844517185,15.491803278688524,15.492957746478874,15.52,7.957957957957958,7.94044665012407,6.901217861975643,6.651376146788991,10.194174757281553,10.303030303030303,2.7656477438136826,2.735562310030395,2.766798418972332,2.610441767068273,2.816901408450704,2.7439024390243905,3.5190615835777126,3.5114503816793894,3.498542274052478,3.5058430717863107,3.4111310592459607,13.278008298755188,13.333333333333334,13.406593406593407,48.33997343957503,48.405466970387245,30.87649402390438,30.794341675734493,30.72289156626506,30.837359098228664,10.53864168618267,10.476190476190476,2.484472049689441,2.6101141924959217,2.5280898876404496,16.844919786096256,16.813048933500628,16.852589641434264,16.877637130801688,4.536082474226804,4.7913446676970635,4.741379310344827,4.690431519699812,12.948517940717629,12.934631432545201,12.914691943127963,12.837837837837839,12.884834663625998,13.35149863760218,13.27102803 ...
