# %% [raw]
# ---
# title: Auto Ownership
# date: today
# ---

# %%
import os
import toml
import pandas as pd
import numpy as np
import validation_data_input
import plotly.express as px

# to show plotly figures in quarto HTML file
import plotly.io as pio

# %store -r validation_data

pio.renderers.default = "plotly_mimetype+notebook_connected"

# auto ownership
#config = toml.load(os.path.join(os.getcwd(), 'validation_configuration.toml'))
config = toml.load(os.path.join(os.getcwd(), 'validation_configuration.toml'))

# %% [markdown]
# ## Household data
#
# - income, hh density, employment density grouped into very low, low, medium, medium-high and high

# %%
# read data
#land_use = pd.read_csv(config['p_survey_landuse'], usecols=['zone_id','log_emptot_1','log_hh_1'])
land_use = validation_data.land_use[['zone_id','log_emptot_1','log_hh_1']].copy()

# hh_data = validation_data_input.get_households_data(['home_zone_id','auto_ownership','hhsize','num_workers','num_adults','num_drivers','income'])
hh_data = validation_data.hh_data_uncloned.copy()
# delete shared data
del validation_data

hh_data = hh_data.merge(land_use,how="left",left_on='home_zone_id',right_on='zone_id').\
    merge(pd.read_csv(config['p_maz_bg_lookup'])[['MAZ', 'block_group_id']], how="left",left_on='home_zone_id',right_on='MAZ')

# grouping income, hh density, employment density into very low, low, medium, medium-high and high
# todo: check if we should be using model data for grouping
var_group = hh_data.loc[hh_data['source']=="model results", ['income','log_emptot_1','log_hh_1']].quantile([.125, .25, .50, .75])

var_group
# Out:
#          income  log_emptot_1  log_hh_1
# 0.125   24000.0      1.321043  4.434358
# 0.250   43000.0      2.922615  5.089858
# 0.500   82000.0      4.726863  5.721498
# 0.750  135000.0      6.239594  6.457123

# %%
# data manipulation

# add income group
hh_data['hhincome_group'] = pd.cut(hh_data['income'],bins=[-9999999.0] + var_group['income'].tolist() + [9999999.0], labels=['very low', 'low', 'medium', 'medium-high', 'high'])
# add hh density groups
hh_data['hh_density_group'] = pd.cut(hh_data['log_hh_1'],bins=[-9999999.0] + var_group['log_hh_1'].tolist() + [9999999.0], labels=['very low', 'low', 'medium', 'medium-high', 'high'])
# add employment density groups
hh_data['emp_density_group'] = pd.cut(hh_data['log_emptot_1'],bins=[-9999999.0] + var_group['log_emptot_1'].tolist() + [9999999.0], labels=['very low', 'low', 'medium', 'medium-high', 'high'])

# add auto_ownership with 4+
hh_data['auto_ownership_simple'] = np.where(hh_data['auto_ownership']>=4, "4+", hh_data['auto_ownership'])
# add auto_ownership with 2+
hh_data['auto_ownership_2'] = np.where(hh_data['auto_ownership']<2, hh_data['auto_ownership'], "2+")
# add hhsize with 4+
hh_data['hhsize_simple'] = np.where(hh_data['hhsize']>=4, "4+", hh_data['hhsize'])
# add num_workers with 4+
hh_data['num_workers_simple'] = np.where(hh_data['num_workers']>=4, "4+", hh_data['num_workers'])
# add num_adults with 4+
hh_data['num_adults_simple'] = np.where(hh_data['num_adults']>=4, "4+",hh_data['num_adults'])
# add num_drivers with 4+
hh_data['num_drivers_simple'] = np.where(hh_data['num_drivers']>=4, "4+",hh_data['num_drivers'])

# %% [markdown]
# ## Auto ownership across all households

# %%
df_plot = hh_data.groupby(['source','auto_ownership_simple'])['hh_weight'].sum().reset_index()

df_plot['percentage'] = df_plot.groupby(['source'], group_keys=False)['hh_weight'].\
        apply(lambda x: 100 * x / float(x.sum()))
df_plot['source'] = df_plot['source'].astype(pd.CategoricalDtype(['model results', 'survey data', 'unweighted survey']))

fig = px.bar(df_plot.sort_values(by=['source']), x="auto_ownership_simple", y="percentage", color="source",
             barmode="group",template="simple_white",
             title="Auto ownership")
fig.update_layout(height=400, width=700, font=dict(size=11))
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="1865aeec-b23a-40a8-9826-7859e98e2fb6" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1865aeec-b23a-40a8-9826-7859e98e2fb6")) {                    Plotly.newPlot(                        "1865aeec-b23a-40a8-9826-7859e98e2fb6",                        [{"alignmentgroup":"True","hovertemplate":"source=model results<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[6.553256382287513,32.693770428895455,39.44132519095002,15.259617894388645,6.052030103478371],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[10.028946661008439,30.280581116184297,36.24995233224641,15.352374806841679,8.088145083719175],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=unweighted survey<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"unweighted survey","marker":{"color":"#2CA02C","pattern":{"shape":""}},"name":"unweighted survey","offsetgroup":"unweighted survey","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[16.143130292269873,44.3048347446053,28.87189292543021,7.402349084949467,3.2777929527451515],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0 ...

# %% [markdown]
# ## Auto ownership by segments

# %%
# auto ownership in Income groups
def plot_auto(df:pd.DataFrame, var:str, title_cat:str,sub_name:str):
    print(f"n=\n"
          f"{df.loc[df['source']=='model results',var].value_counts()[df[var].sort_values().unique()]}")
    df_plot = df.groupby(['source',var,'auto_ownership_simple'])['hh_weight'].sum().reset_index()
    df_plot['percentage'] = df_plot.groupby(['source',var], group_keys=False)['hh_weight'].\
        apply(lambda x: 100 * x / float(x.sum()))

    fig = px.bar(df_plot, x="auto_ownership_simple", y="percentage", color="source",
                 facet_col=var, barmode="group",template="simple_white",
                 title="Auto ownership by "+ title_cat)
    fig.for_each_annotation(lambda a: a.update(text = sub_name + "=<br>" + a.text.split("=")[-1]))
    fig.update_xaxes(title_text="n of cars")
    fig.update_layout(height=400, width=800, font=dict(size=11))
    fig.show()

# %% [raw]
# ::: {.panel-tabset}

# %% [raw]
# ### Income

# %%
plot_auto(hh_data,'hhincome_group','income level', 'Income')
# Out:
# n=
# very low       202751
# low            198701
# medium         402805
# medium-high    404394
# high           396612
# Name: hhincome_group, dtype: int64
# <div>                            <div id="d8a228f0-65cf-41b8-a5b8-017fca85ec58" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d8a228f0-65cf-41b8-a5b8-017fca85ec58")) {                    Plotly.newPlot(                        "d8a228f0-65cf-41b8-a5b8-017fca85ec58",                        [{"alignmentgroup":"True","hovertemplate":"source=model results<br>hhincome_group=very low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[21.345887319914574,55.992818777712564,18.03147703340551,3.7829653121316293,0.8468515568357247],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>hhincome_group=low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[10.251080769598543,49.25088449479369,32.01493701591839,6.2470747505045265,2.2360229691848557],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>hhincome_group=medium<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[5.553555690718834,39.109991186802546,39.30313675351597,10.774444209977533,5.258872158985117],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>hhincome_group=medium-high<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":[2.9980662423280267,22.50478493746198,44.69601428310015,19.756475120798033,10.044659416311815],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>hhincome_group=high<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x5","y":[1.778816576402126,16.360574062307748,48.88934273294807,25.611933073129407,7.359333555212651],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>hhincome_group=very low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[22.073179837692063,31.83251202716988,25.212536956844495,12.285825079518014,8.595946098775551],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>hhincome_group=low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[21.12121340814347,51 ...

# %% [raw]
# ### Household size

# %%
plot_auto(hh_data,'hhsize_simple','household size', 'HH size')
# Out:
# n=
# 1     452162
# 2     533682
# 3     254336
# 4+    365083
# Name: hhsize_simple, dtype: int64
# <div>                            <div id="117eb173-d065-4893-838d-d41614810868" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("117eb173-d065-4893-838d-d41614810868")) {                    Plotly.newPlot(                        "117eb173-d065-4893-838d-d41614810868",                        [{"alignmentgroup":"True","hovertemplate":"source=model results<br>hhsize_simple=1<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[15.610334349193431,61.59451700939044,17.397525665580037,4.065357106523768,1.3322658693123262],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>hhsize_simple=2<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[4.250471254417425,28.022867550338965,51.253742865601616,13.06058664148313,3.4123316881588663],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>hhsize_simple=3<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[2.1444073980875693,18.04070206341218,44.75025163563161,26.846769627579267,8.217869275289381],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>hhsize_simple=4+<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":[1.7735692979404682,13.93573516159339,45.7769876986877,24.266262740253588,14.247445101524859],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>hhsize_simple=1<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[26.222698228075334,61.03013582394062,8.387120952277733,2.5498781385890816,1.8101668571172287],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>hhsize_simple=2<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[3.155963628669488,18.62827538434212,57.92236913723712,13.479332800483041,6.814059049268236],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>hhsize_simple=3<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[1.3725078284446455,11.104902984667488,44.05184163274985,34.78506846975467 ...

# %% [raw]
# ### Number of adults

# %%
plot_auto(hh_data.loc[hh_data['num_adults_simple']!="0"],'num_adults_simple','number of adults','num adults')
# Out:
# n=
# 1     504125
# 2     762899
# 3     240181
# 4+     97983
# Name: num_adults_simple, dtype: int64
# <div>                            <div id="23a94087-df7f-4c1b-8888-16dfde189f30" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("23a94087-df7f-4c1b-8888-16dfde189f30")) {                    Plotly.newPlot(                        "23a94087-df7f-4c1b-8888-16dfde189f30",                        [{"alignmentgroup":"True","hovertemplate":"source=model results<br>num_adults_simple=1<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[14.785221919166874,61.17966774113563,18.468633771386067,4.2128440366972475,1.353632531614183],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>num_adults_simple=2<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[3.1272815929762654,23.706545689534263,53.46998750817605,15.448571829298505,4.247613380014917],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>num_adults_simple=3<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[1.482215495813574,11.69659548423897,41.01864843597121,32.761125984153615,13.041414599822634],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>num_adults_simple=4+<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":[3.2883255258565263,7.5574334323300985,34.27533347621526,27.73236173621955,27.146545829378567],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>num_adults_simple=1<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[25.87860313137285,60.97185418265503,8.812533345687722,2.5347098514086057,1.802299488875786],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>num_adults_simple=2<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[2.4226642870064783,16.29930927373381,59.74703979242811,15.187281985825427,6.343704661006168],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>num_adults_simple=3<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[0.6908297736760529,10.93703223271997,28.00563 ...

# %% [raw]
# ### Number of workers

# %%
plot_auto(hh_data,'num_workers_simple','number of workers','num workers')
# Out:
# n=
# 0     355309
# 1     637690
# 2     504466
# 3      99225
# 4+      8573
# Name: num_workers_simple, dtype: int64
# <div>                            <div id="53eed648-5e49-4584-859b-482d5c72fac0" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("53eed648-5e49-4584-859b-482d5c72fac0")) {                    Plotly.newPlot(                        "53eed648-5e49-4584-859b-482d5c72fac0",                        [{"alignmentgroup":"True","hovertemplate":"source=model results<br>num_workers_simple=0<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[12.547106884430171,49.78145782966376,28.69220875350751,6.817727668029799,2.161498864368761],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>num_workers_simple=1<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[7.534068277689786,40.13768445482915,36.672677946964825,11.41024635794822,4.245322962568019],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>num_workers_simple=2<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[2.140282992312663,16.722038749886018,50.79271943005079,22.03637113303969,8.308587694710843],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>num_workers_simple=3<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":[1.363567649281935,7.344923154446964,38.42479213907785,34.79365079365079,18.073066263542454],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>num_workers_simple=4+<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x5","y":[4.922430887670593,4.012597690423422,34.69030677709087,26.606788755394845,29.767875889420274],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>num_workers_simple=0<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[28.042812498272667,42.8011151840597,18.247501675565644,6.913391057645494,3.9951795844564892],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>num_workers_simple=1<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[10.48440911190376,45.0829780886265,3 ...

# %% [raw]
# ### Number of drivers

# %%
plot_auto(hh_data.loc[hh_data['num_drivers_simple']!="0"],'num_drivers_simple','number of drivers','num drivers')
# Out:
# n=
# 1     493312
# 2     708568
# 3     274525
# 4+    128847
# Name: num_drivers_simple, dtype: int64
# <div>                            <div id="207ed7d6-2dab-4c9a-a51f-b1760fcea171" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("207ed7d6-2dab-4c9a-a51f-b1760fcea171")) {                    Plotly.newPlot(                        "207ed7d6-2dab-4c9a-a51f-b1760fcea171",                        [{"alignmentgroup":"True","hovertemplate":"source=model results<br>num_drivers_simple=1<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[15.016865594187857,61.86490496886352,17.72488810326933,4.067405617540218,1.3259357161390763],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>num_drivers_simple=2<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[3.379915547978458,25.2656061239006,54.983995890302694,13.009901660814489,3.3605807770037597],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>num_drivers_simple=3<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[1.3754667152354065,11.583280211274019,41.311720244057916,34.74911210272288,10.980420726709772],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>num_drivers_simple=4+<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":[2.6263708118931754,6.836014808260961,33.13076749943732,28.959153104069166,28.447693776339378],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>num_drivers_simple=1<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[25.913785788629944,60.96551542496017,8.777793165234078,2.5381558576515078,1.8047497635242997],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>num_drivers_simple=2<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[2.506809808505638,16.723265276250864,60.09321978564419,15.029416648520993,5.6472884810783155],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>num_drivers_simple=3<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[0.9105581260316811,8.41546445269251 ...

# %% [raw]
# ### Household density

# %%
plot_auto(hh_data.dropna(subset=['hh_density_group']),'hh_density_group','household density','density')
# Out:
# n=
# very low       200677
# low            200647
# medium         401318
# medium-high    401356
# high           401265
# Name: hh_density_group, dtype: int64
# <div>                            <div id="a4dfb13f-10cd-4ed3-b848-b2cdc67bdbb1" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a4dfb13f-10cd-4ed3-b848-b2cdc67bdbb1")) {                    Plotly.newPlot(                        "a4dfb13f-10cd-4ed3-b848-b2cdc67bdbb1",                        [{"alignmentgroup":"True","hovertemplate":"source=model results<br>hh_density_group=very low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.21527130662706737,10.611081489159195,41.91960214673331,31.772948569093618,15.481096488386811],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>hh_density_group=low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[0.8148639152342173,19.259694887040425,47.10960044256829,23.434688781790907,9.38115197336616],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>hh_density_group=medium<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[1.8476619538620247,26.905845239934415,46.31813175586443,18.103100284562366,6.825260765776766],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>hh_density_group=medium-high<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":[4.754133487477452,39.724085350661255,40.69554211223951,10.994229561785547,3.832009487836235],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>hh_density_group=high<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x5","y":[19.09810225162922,49.21186746912888,26.235280924077603,4.335788070227904,1.1189612849363886],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>hh_density_group=very low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[2.192862094753443,21.595043241702058,34.390463070971535,22.627056323166336,19.194575269406634],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>hh_density_group=low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[4.448 ...

# %% [raw]
# ### Employment density

# %%
plot_auto(hh_data.dropna(subset=['emp_density_group']),'emp_density_group','employment density','density')
# Out:
# n=
# very low       200684
# low            200685
# medium         401476
# medium-high    401132
# high           401286
# Name: emp_density_group, dtype: int64
# <div>                            <div id="62dfda43-13ee-4301-9e47-ddb5a8fc3869" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("62dfda43-13ee-4301-9e47-ddb5a8fc3869")) {                    Plotly.newPlot(                        "62dfda43-13ee-4301-9e47-ddb5a8fc3869",                        [{"alignmentgroup":"True","hovertemplate":"source=model results<br>emp_density_group=very low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.19284048553945507,12.458392298339678,43.815152179545954,29.22056566542425,14.313049371150665],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>emp_density_group=low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":[0.4823479582430177,17.30672446869472,46.27450980392157,25.077609188529287,10.858808580611406],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>emp_density_group=medium<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":[1.6250037362133727,27.29328776813558,46.17312118283534,18.136825115324452,6.771762197491257],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>emp_density_group=medium-high<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":[4.894648145747534,39.72806956313632,40.684612546493426,11.089367091132097,3.6033026534906214],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results<br>emp_density_group=high<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"model results","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x5","y":[19.358761581515427,48.880100476966554,25.858863753033997,4.65777525256301,1.244498935921014],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>emp_density_group=very low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":[0.8576418080888141,15.100813278918936,43.394360913212466,22.223097743384415,18.424086256395363],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data<br>emp_density_group=low<br>auto_ownership_simple=%{x}<br>percentage=%{y}<extra></extra>","legendgroup":"survey data","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2"," ...

# %% [raw]
# :::

# %% [markdown]
# ## Validate auto ownership with ACS vehicle ownership data
#
# - TO-DO:
#     1. get auto ownership values [0,1,2,3,4+] from ACS data.
#     2. check block_group_id values: not matching ACS block group IDs
#
# - household counts in ACS data

# %%
print(f"n=\n"
      f"{hh_data.loc[hh_data['source']=='model results','auto_ownership_2'].value_counts()[hh_data['auto_ownership_2'].sort_values().unique()]}")
      
df = hh_data.groupby(['source','block_group_id','auto_ownership_2'])['hh_weight'].sum().reset_index()
# df_plot = df_plot.loc[df_plot['auto_ownership_2']!="-1"]

df['percentage'] = df.groupby(['source','block_group_id'], group_keys=False)['hh_weight'].\
    apply(lambda x: 100 * x / float(x.sum()))

# acs auto ownership data
acs_auto_ownership = pd.read_csv(config['p_acs_auto_ownership'])[['cars_none_control', 'cars_one_control', 'cars_two_or_more_control', 'block_group_id']]

# calculate percentage of households having 0, 1 or 2+ vehicle(s) in each block group
acs_auto_ownership['total'] = acs_auto_ownership['cars_one_control'] + acs_auto_ownership['cars_two_or_more_control'] + acs_auto_ownership['cars_none_control']
acs_auto_ownership['0'] = 100 * acs_auto_ownership['cars_none_control']/acs_auto_ownership['total']
acs_auto_ownership['1'] = 100 * acs_auto_ownership['cars_one_control']/acs_auto_ownership['total']
acs_auto_ownership['2+'] = 100 * acs_auto_ownership['cars_two_or_more_control']/acs_auto_ownership['total']
acs_auto_ownership['source'] = "acs data"
bg_auto_ownership = acs_auto_ownership[['source','block_group_id','0','1','2+']]
bg_auto_ownership = pd.melt(bg_auto_ownership, id_vars=['source','block_group_id'], value_vars=['0','1','2+'], var_name='auto_ownership_2',value_name='percentage')

# combine both sets of data
col_list = ['source','block_group_id','auto_ownership_2','percentage']
bg_auto_ownership = pd.concat([df[col_list].copy(),
                               bg_auto_ownership[col_list].copy()])

# bg_auto_ownership
# Out:
# n=
# 0     105197
# 1     524821
# 2+    975245
# Name: auto_ownership_2, dtype: int64

# %% [markdown]
# - scatterplot

# %%
df_plot = pd.pivot(bg_auto_ownership, index=['block_group_id','auto_ownership_2'], columns='source', values='percentage').reset_index()



fig = px.scatter(df_plot, x="acs data", y="model results", trendline="ols", trendline_color_override='rgb(136, 136, 136)',
                 template="plotly_white",
                 facet_col='auto_ownership_2', height=400, width=1000,
                 title="Auto ownership model results validation with acs data")
fig.update_xaxes(dtick=20)
fig.update_yaxes(dtick=20,range=[0, 100])
fig.update_traces(marker_size=3)
fig.update_layout(height=360, width=800, font=dict(size=11))
fig.show()
# Out:
# <div>                            <div id="61223172-86d2-4bcf-8987-3d79dd0149c6" class="plotly-graph-div" style="height:360px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("61223172-86d2-4bcf-8987-3d79dd0149c6")) {                    Plotly.newPlot(                        "61223172-86d2-4bcf-8987-3d79dd0149c6",                        [{"hovertemplate":"auto_ownership_2=0<br>acs data=%{x}<br>model results=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle","size":3},"mode":"markers","name":"","showlegend":false,"x":[18.081180811808117,18.181818181818183,18.170580964153277,18.206278026905828,18.093699515347335,6.292134831460674,6.172839506172839,6.292134831460674,6.216696269982238,6.301369863013699,6.25,6.118546845124283,6.109324758842444,25.75835475578406,25.869262865090402,25.720384204909283,18.317757009345794,18.313253012048193,18.076285240464344,18.226002430133658,1.937984496124031,1.9337016574585635,2.0361990950226243,8.81294964028777,8.814102564102564,8.734939759036145,8.827586206896552,8.709677419354838,8.848080133555927,12.251941328731665,12.162162162162161,12.171837708830548,12.280701754385966,1.6842105263157894,1.9031141868512111,2.3706896551724137,2.4630541871921183,5.277044854881266,4.926108374384237,6.509945750452079,6.410256410256411,21.26865671641791,21.296296296296298,21.220723917672107,21.221374045801525,21.25,13.583138173302109,13.612565445026178,13.607188703465981,7.751937984496124,7.581227436823105,7.6923076923076925,7.73286467486819,3.5714285714285716,3.6713286713286712,4.585537918871252,4.6263345195729535,4.704301075268817,18.418079096045197,18.403908794788272,18.315018315018314,13.836477987421384,13.84297520661157,13.855421686746988,13.612565445026178,5.327245053272451,5.180722891566265,5.2439024390243905,12.997658079625293,12.947189097103918,13.102119460500964,8.131067961165048,7.982261640798226,8.108108108108109,3.8461538461538463,3.7914691943127963,3.9244186046511627,4.355108877721943,4.370629370629371,4.120443740095087,4.08997955010225,2.763819095477387,2.7848101265822787,2.6970954356846475,6.6115702479338845,6.5349544072948325,6.11353711790393,6.214689265536723,6.175771971496437,6.265664160401003,2.2257551669316373,2.3465703971119134,2.1782178217821784,2.304147465437788,7.885304659498208,8.045977011494253,7.9245283018867925,7.861635220125786,5.007153075822604,5.007824726134586,5.040650406504065,2.8368794326241136,2.848575712143928,2.9535864978902953,2.8776978417266186,3.476482617586912,3.522504892367906,3.5587188612099645,3.5335689045936394,3.5398230088495577,11.041666666666666,11.006711409395972,11.052166224580018,10.943912448700411,11.075949367088608,11.02661596958175,10.944206008583691,7.6923076923076925,7.763401109057301,7.769423558897243,7.741935483870968,7.829181494661921,5.166051660516605,5.009633911368016,5.208333333333333,10.714285714285714,10.703363914373089,10.606060606060606,15.46644844517185,15.491803278688524,15.492957746478874,15.52,7.957957957957958,7.94044665012407,6.901217861975643,6.651376146788991,10.194174757281553,10.303030303030303,2.7656477438136826,2.735562310030395,2.766798418972332,2.610441767068273,2.816901408450704,2.7439024390243905,3.5190615835777126,3.5114503816793894,3.498542274052478,3.5058430717863107,3.4111310592459607,13.278008298755188,13.333333333333334,13.406593406593407,48.33997343957503,48.405466970387245,30.87649402390438,30.794341675734493,30.72289156626506,30.837359098228664,10.53864168618267,10.476190476190476,2.484472049689441,2.6101141924959217,2.5280898876404496,16.844919786096256,16.813048933500628,16.852589641434264,16.877637130801688,4.536082474226804,4.7913446676970635,4.741379310344827,4.690431519699812,12.948517940717629,12.934631432545201,12.914691943127963,12.837837837837839,12.884834663625998,13.35149863760218,13.27102803 ...
