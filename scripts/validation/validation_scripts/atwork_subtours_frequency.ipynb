# %% [raw]
# ---
# title: At-work Subtours Frequency
# date: today
# ---

# %% [markdown]
# The at-work subtour frequency model selects the number of at-work subtours made for each work tour.
#
# - work tours Alternatives: none, 1 eating out tour, 1 business tour, 1 maintenance tour, 2 business tours, 1 eating out tour + 1 business tour
# - Explanatory variables include employment status, income, auto ownership, the frequency of other tours, characteristics of the parent work tour, and characteristics of the workplace zone.

# %%
import os
import toml
import pandas as pd
import numpy as np
import plotly.express as px
import validation_data_input
import psrc_theme

import plotly.io as pio
pio.renderers.default = "plotly_mimetype+notebook_connected" # to show plotly figures in quarto HTML file
pio.templates.default = "simple_white+psrc_color" # set plotly template

# run get_data.ipynb to load validation data
# %store -r validation_data

config = toml.load(os.path.join(os.getcwd(), 'validation_configuration.toml'))

# %%
tour_data = validation_data.tours_cleaned.copy()
per_data = validation_data.persons_data_uncloned.copy()
hh_data = validation_data.hh_data_uncloned.copy()

# %%
# select all work tours that could make atwork subtours
work_tour = tour_data.loc[tour_data['tour_type']=="work"].copy()
work_tour['atwork_subtour_frequency_count'] = 0
work_tour.loc[work_tour['atwork_subtour_frequency'].isin(['eat','maint','business1']),'atwork_subtour_frequency_count'] = 1
work_tour.loc[work_tour['atwork_subtour_frequency'].isin(['eat_business','business2']),'atwork_subtour_frequency_count'] = 2

# %%
df_plot = work_tour.groupby(['source','atwork_subtour_frequency_count'])['tour_weight'].sum().reset_index()
df_plot['percentage'] = df_plot.groupby(['source'], group_keys=False)['tour_weight']. \
    apply(lambda x: x / float(x.sum()))
fig1 = px.bar(df_plot, x='atwork_subtour_frequency_count', y="percentage", color="source", barmode="group",
              title="atwork subtours frequency")
fig1.for_each_annotation(lambda a: a.update(text = a.text.split("=")[-1]))
fig1.update_layout(height=400, width=700, font=dict(size=11), yaxis=dict(tickformat=".1%"))
fig1.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="730306b7-68d8-44fb-bb63-dd0fe345d6c0" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("730306b7-68d8-44fb-bb63-dd0fe345d6c0")) {                    Plotly.newPlot(                        "730306b7-68d8-44fb-bb63-dd0fe345d6c0",                        [{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003eatwork_subtour_frequency_count=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"i1","bdata":"AAEC"},"xaxis":"x","y":{"dtype":"f8","bdata":"5\u002fz7c6iX5j9olCHsO43SP2hynPnK3HA\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data\u003cbr\u003eatwork_subtour_frequency_count=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey data","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"i1","bdata":"AA=="},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAA8D8="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=unweighted survey\u003cbr\u003eatwork_subtour_frequency_count=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"unweighted survey","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"unweighted survey","offsetgroup":"unweighted survey","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"i1","bdata":"AA=="},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAA8D8="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.111111 ...

# %%
df_plot = work_tour.groupby(['source','atwork_subtour_frequency'])['tour_weight'].sum().reset_index()
df_plot['percentage'] = df_plot.groupby(['source'], group_keys=False)['tour_weight']. \
    apply(lambda x: x / float(x.sum()))
fig1 = px.bar(df_plot.loc[df_plot['atwork_subtour_frequency']!='no_subtours'], x='atwork_subtour_frequency', y="percentage", color="source", barmode="group",
              category_orders={"atwork_subtour_frequency": ['no_subtours','eat','maint','business1','eat_business','business2']},
              title="atwork subtours frequency by purpose (excluding no_subtours)")
fig1.for_each_annotation(lambda a: a.update(text = a.text.split("=")[-1]))
fig1.update_layout(height=400, width=700, font=dict(size=11), yaxis=dict(tickformat=".1%"))
fig1.show()
# Out:
# C:\Users\Modeller\AppData\Local\Temp\ipykernel_3732\3748877180.py:1: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="efb85256-aaf0-4049-b711-77eda7d69b5a" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("efb85256-aaf0-4049-b711-77eda7d69b5a")) {                    Plotly.newPlot(                        "efb85256-aaf0-4049-b711-77eda7d69b5a",                        [{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003eatwork_subtour_frequency=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":true,"textposition":"auto","x":["eat","business1","maint","business2","eat_business",""],"xaxis":"x","y":{"dtype":"f8","bdata":"fyeVzz0vyz8EXaPWJ\u002fClP0CoFEzAvKE\u002f1eWednYzWD\u002fmcem32p9lPwAAAAAAAAAA"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data\u003cbr\u003eatwork_subtour_frequency=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey data","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":true,"textposition":"auto","x":["eat","business1","maint","business2","eat_business",""],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=unweighted survey\u003cbr\u003eatwork_subtour_frequency=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"unweighted survey","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"unweighted survey","offsetgroup":"unweighted survey","orientation":"v","showlegend":true,"textposition":"auto","x":["eat","business1","maint","business2","eat_business",""],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002f"},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666, ...

# %%
# add auto_ownership with 4+
hh_data['auto_ownership_simple'] = hh_data['auto_ownership'].apply(lambda x: "4+" if x>=4.0 else str(x))

# add income group
var_group = hh_data.loc[hh_data['source']=="model results", ['income']].quantile([.125, .25, .50, .75])
hh_data['hhincome_group'] = pd.cut(hh_data['income'],bins=[-9999999.0] + var_group['income'].tolist() + [9999999.0], labels=['very low', 'low', 'medium', 'medium-high', 'high'])

# add person type labels
ptype_cat = {1: "1: Full-Time Worker",
             2: "2: Part-Time Worker",
             3: "3: University Student",
             4: "4: Non-Working Adult Age <65",
             5: "5: Non-Working Adult Age 65+",
             6: "6: High School Student Age 16+",
             7: "7: Child Age 5-15",
             8: "8: Child Age 0-4"}
per_data['ptype_label'] = per_data['ptype'].map(ptype_cat)

per_data = per_data.merge(hh_data[['household_id','income','hhincome_group','auto_ownership_simple','source']],
                          how='left', on=['household_id','source']) # get auto ownership from hh data
work_tour = work_tour.merge(per_data, how='left', on=['person_id','household_id','source'])

# %% [markdown]
# ## atwork subtours frequency by segment

# %%
def plot_atwork_subtour(df:pd.DataFrame, var:str, title_cat:str,sub_name:str):
    df_plot = df.groupby(['source',var,'atwork_subtour_frequency'])['tour_weight'].sum().reset_index()
    df_plot['percentage'] = df_plot.groupby(['source',var], group_keys=False)['tour_weight']. \
        apply(lambda x: x / float(x.sum()))

    fig = px.bar(df_plot.loc[df_plot['atwork_subtour_frequency']!='no_subtours'],
                 x="atwork_subtour_frequency", y="percentage", color="source",
                 facet_col=var, barmode="group",
                 category_orders={"atwork_subtour_frequency": ['eat','maint','business1','eat_business','business2']},
                 title="atwork subtour frequency by "+ title_cat)
    fig.for_each_annotation(lambda a: a.update(text = sub_name + "=<br>" + a.text.split("=")[-1]))
    fig.update_xaxes(title_text="")
    fig.update_layout(height=400, width=850, yaxis=dict(tickformat=".1%"))
    fig.show()

# %% [raw]
# :::{.panel-tabset}
# ### auto ownership

# %%
plot_atwork_subtour(work_tour,'auto_ownership_simple',"auto ownership","vehicle")
# Out:
# C:\Users\Modeller\AppData\Local\Temp\ipykernel_3732\2427850617.py:2: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="e2e4c839-840e-4bdb-9455-a30b6cd621f0" class="plotly-graph-div" style="height:400px; width:850px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e2e4c839-840e-4bdb-9455-a30b6cd621f0")) {                    Plotly.newPlot(                        "e2e4c839-840e-4bdb-9455-a30b6cd621f0",                        [{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003eauto_ownership_simple=0\u003cbr\u003eatwork_subtour_frequency=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":true,"textposition":"auto","x":["eat","business1","maint","business2","eat_business",""],"xaxis":"x","y":{"dtype":"f8","bdata":"JeJQhJg4xz\u002fBjnmnUQCQPzl6c\u002fagtZc\u002fuSWPYlDrPD8mBS39nENFPwAAAAAAAAAA"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003eauto_ownership_simple=1\u003cbr\u003eatwork_subtour_frequency=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["eat","business1","maint","business2","eat_business",""],"xaxis":"x2","y":{"dtype":"f8","bdata":"JF3bdffWyj9vwWthw2GjP7ZpbG+jq6E\u002feNYrY\u002f8qUz+fXmO5EwJkPwAAAAAAAAAA"},"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003eauto_ownership_simple=2\u003cbr\u003eatwork_subtour_frequency=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["eat","business1","maint","business2","eat_business",""],"xaxis":"x3","y":{"dtype":"f8","bdata":"08jUCFSxyz9+UWLikC+nP8SqwuPhGKI\u002fOz+9S2IuWz9IcM54SfBmPwAAAAAAAAAA"},"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003eauto_ownership_simple=3\u003cbr\u003eatwork_subtour_frequency=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["eat","business1","maint","business2","eat_business",""],"xaxis":"x4","y":{"dtype":"f8","bdata":"B9JSfXNgyz+1e0CWhV+oP24qeSFGJaI\u002fYvyNw0dcWz+\u002fTxW1EptmPwAAAAAAAAAA"},"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003eauto_ownership_simple=4+\u003cbr\u003eatwork_subtour_frequency=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["eat","business1","maint","business2","eat_business",""],"xaxis":"x5","y":{"dtype":"f8","bdata":"5wCrHCDfyj8eqPHkp+mnP99H6YbZvKE\u002fPOZHikA0WD+JOYB0nsxoPwAAAAAAAAAA"},"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data\u003cbr\u003eauto_ownership_simple=0\u003cbr\u003eatwork_subtour_frequency=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey data","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey data","o ...

# %% [raw]
# ### household income

# %%
plot_atwork_subtour(work_tour,'hhincome_group',"household income","income")
# Out:
# C:\Users\Modeller\AppData\Local\Temp\ipykernel_3732\2427850617.py:2: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# C:\Users\Modeller\AppData\Local\Temp\ipykernel_3732\2427850617.py:3: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="202e1491-92ce-4cb3-a448-4f875ae39389" class="plotly-graph-div" style="height:400px; width:850px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("202e1491-92ce-4cb3-a448-4f875ae39389")) {                    Plotly.newPlot(                        "202e1491-92ce-4cb3-a448-4f875ae39389",                        [{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003ehhincome_group=very low\u003cbr\u003eatwork_subtour_frequency=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":true,"textposition":"auto","x":["eat","business1","maint","business2","eat_business",""],"xaxis":"x","y":{"dtype":"f8","bdata":"NSKI3tDWtT9vVFoizQKPP9SwQusVEqA\u002fgR+XRTjfMj+Lh8o\u002fnkxBPwAAAAAAAAAA"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003ehhincome_group=low\u003cbr\u003eatwork_subtour_frequency=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["eat","business1","maint","business2","eat_business",""],"xaxis":"x2","y":{"dtype":"f8","bdata":"mWAJypcBxT9BLvxCdcqaP65PdqYhOKI\u002fFc9HoSoERD+1AsYEhb9XPwAAAAAAAAAA"},"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003ehhincome_group=medium\u003cbr\u003eatwork_subtour_frequency=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["eat","business1","maint","business2","eat_business",""],"xaxis":"x3","y":{"dtype":"f8","bdata":"5hkcuSEDyz+IcIryUVukPwug\u002fVvvEaI\u002fEOA7\u002fpSmVz\u002ffQ+yeEfNkPwAAAAAAAAAA"},"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003ehhincome_group=medium-high\u003cbr\u003eatwork_subtour_frequency=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["eat","business1","maint","business2","eat_business",""],"xaxis":"x4","y":{"dtype":"f8","bdata":"\u002fRAO3aVPzT9tq8miV9uoP7XcgwSL2KE\u002fqMq8nxcdXD9PFEj7tAlpPwAAAAAAAAAA"},"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003ehhincome_group=high\u003cbr\u003eatwork_subtour_frequency=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["eat","business1","maint","business2","eat_business",""],"xaxis":"x5","y":{"dtype":"f8","bdata":"fcakscRIzT+KEIXYqu6oPxkEd\u002fTOZaE\u002fsHymUy29Wz+ZyqTIzxZoPwAAAAAAAAAA"},"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data\u003cbr\u003ehhincome_group=very low\u003cbr\u003eatwork_subtour_frequency=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey data","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey data"," ...

# %% [raw]
# ### person type

# %%
plot_atwork_subtour(work_tour,'ptype_label',"person type","ptype")
# Out:
# C:\Users\Modeller\AppData\Local\Temp\ipykernel_3732\2427850617.py:2: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="796b4568-38a9-4d14-88c3-fcbb461d158f" class="plotly-graph-div" style="height:400px; width:850px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("796b4568-38a9-4d14-88c3-fcbb461d158f")) {                    Plotly.newPlot(                        "796b4568-38a9-4d14-88c3-fcbb461d158f",                        [{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003eptype_label=1: Full-Time Worker\u003cbr\u003eatwork_subtour_frequency=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":true,"textposition":"auto","x":["eat","business1","maint","business2","eat_business",""],"xaxis":"x","y":{"dtype":"f8","bdata":"bLN\u002f43gxzj+D+kxgLOanP1G8aC7+M6I\u002fd2fCDjhlWD8gpQvfxA9mPwAAAAAAAAAA"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003eptype_label=2: Part-Time Worker\u003cbr\u003eatwork_subtour_frequency=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["eat","business1","maint","business2","eat_business",""],"xaxis":"x2","y":{"dtype":"f8","bdata":"X90lGw1orz\u002fNgiCmmIeTP+inqoCk4Z0\u002fHFoGpdMjWT\u002fiyGq2clVkPwAAAAAAAAAA"},"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003eptype_label=3: University Student\u003cbr\u003eatwork_subtour_frequency=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["eat","business1","maint","business2","eat_business",""],"xaxis":"x3","y":{"dtype":"f8","bdata":"uEwPNdW0qj81p\u002fs4YoOLP51dEuXhrpw\u002fuc75KRKxTT\u002fGZEga3nZaPwAAAAAAAAAA"},"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003eptype_label=4: Non-Working Adult Age \u003c65\u003cbr\u003eatwork_subtour_frequency=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["eat","business1","maint","business2","eat_business",""],"xaxis":"x4","y":{"dtype":"f8","bdata":"AAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002f"},"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003eptype_label=5: Non-Working Adult Age 65+\u003cbr\u003eatwork_subtour_frequency=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["eat","business1","maint","business2","eat_business",""],"xaxis":"x5","y":{"dtype":"f8","bdata":"AAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002fAAAAAAAA+P8AAAAAAAD4\u002fwAAAAAAAPj\u002f"},"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003eptype_label=6: High School Student Age 16+\u003cbr\u003eatwork_subtour_frequency=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u ...

# %% [raw]
# :::
