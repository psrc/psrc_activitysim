# %% [raw]
# ---
# title: Non-mandatory tour frequency
# date: today
# ---

# %%
import os
import toml
import pandas as pd
import numpy as np
import plotly.express as px
import validation_data_input
import psrc_theme
# from plotly.subplots import make_subplots

import plotly.io as pio
pio.renderers.default = "plotly_mimetype+notebook_connected" # to show plotly figures in quarto HTML file
pio.templates.default = "simple_white+psrc_color" # set plotly template

config = toml.load(os.path.join(os.getcwd(), 'validation_configuration.toml'))

# run get_data.ipynb to load validation data
# %store -r validation_data

# %%
# read data
land_use = validation_data.land_use.copy()

per_data = validation_data.persons_data_uncloned.copy()
hh_data = validation_data.hh_data_uncloned.copy()
tour_data = validation_data.tours.copy()

# add auto_ownership with 4+
hh_data['auto_ownership_simple'] = hh_data['auto_ownership'].apply(lambda x: "4+" if x>=4.0 else str(x))

# add person type labels
ptype_cat = {1: "1: Full-Time Worker",
             2: "2: Part-Time Worker",
             3: "3: University Student",
             4: "4: Non-Working Adult Age <65",
             5: "5: Non-Working Adult Age 65+",
             6: "6: High School Student Age 16+",
             7: "7: Child Age 5-15",
             8: "8: Child Age 0-4"}
per_data['ptype_label'] = per_data['ptype'].map(ptype_cat)

# Create distance to work bins: bins of 2 miles up to 46 miles
max_bin = 46
bin_size = 2
per_data['d_work_bin_46mi'] = pd.cut(per_data['distance_to_work'], bins=np.arange(0, max_bin+bin_size, bin_size), labels=[str(i) for i in np.arange(0, max_bin, bin_size)])

# number of mandatory tours
num_non_m_tours = tour_data.loc[tour_data['tour_category']=="non_mandatory"].groupby(['source','person_id']).size().to_frame(). \
    rename(columns={0: 'num_non_mand'})

# all households with joint tours
per_data = pd.merge(per_data, num_non_m_tours, on=['source','person_id'])

per_data['num_non_mand_simple'] = per_data['num_non_mand'].apply(lambda x: "4+" if x>=4.0 else str(x))

per_data = per_data.merge(hh_data[['household_id','auto_ownership','auto_ownership_simple','source']],
                          how='left', on=['household_id','source']) # get auto ownership from hh data

tour_data = tour_data.merge(per_data, how='left', on=['person_id','household_id','source'])
non_m_tour_data = tour_data.loc[tour_data['tour_category']=="non_mandatory"]

# total number of persons by source
df_person_count = per_data.groupby('source')['person_weight'].sum().reset_index()

# %% [markdown]
# ## non-mandatory tours per person

# %%
df_plot = non_m_tour_data.\
    groupby(['source','tour_category'])[['tour_weight']].sum().reset_index(). \
    merge(df_person_count, how='left', on='source')
df_plot['tour_cat_rate'] = df_plot['tour_weight']/df_plot['person_weight']

fig = px.bar(df_plot, x="tour_category", y="tour_cat_rate", color="source",barmode="group",
             title="non-mandatory tour rates")
fig.update_layout(height=400, width=500, font=dict(size=11))
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="84f09b24-af51-4c86-a8ca-a35dc9092152" class="plotly-graph-div" style="height:400px; width:500px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("84f09b24-af51-4c86-a8ca-a35dc9092152")) {                    Plotly.newPlot(                        "84f09b24-af51-4c86-a8ca-a35dc9092152",                        [{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003etour_category=%{x}\u003cbr\u003etour_cat_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":true,"textposition":"auto","x":["non_mandatory"],"xaxis":"x","y":{"dtype":"f8","bdata":"mBFFEA3u9z8="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data\u003cbr\u003etour_category=%{x}\u003cbr\u003etour_cat_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey data","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":true,"textposition":"auto","x":["non_mandatory"],"xaxis":"x","y":{"dtype":"f8","bdata":"gU5gNGZu+j8="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=unweighted survey\u003cbr\u003etour_category=%{x}\u003cbr\u003etour_cat_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"unweighted survey","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"unweighted survey","offsetgroup":"unweighted survey","orientation":"v","showlegend":true,"textposition":"auto","x":["non_mandatory"],"xaxis":"x","y":{"dtype":"f8","bdata":"YwGdw7RrBEA="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26 ...

# %%
df_plot = per_data.groupby(['num_non_mand','source'])['person_weight'].sum().reset_index()

df_plot['percentage'] = df_plot.groupby(['source'], group_keys=False)['person_weight']. \
    apply(lambda x: x / float(x.sum()))

fig = px.bar(df_plot, x="num_non_mand", y="percentage", color="source",barmode="group",
             title="number of non mandatory tours in a day")
fig.update_layout(height=400, width=700, yaxis=dict(tickformat=".2%"))
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="16d3f9b6-ff8f-45ce-a5e1-05e29a57aad6" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("16d3f9b6-ff8f-45ce-a5e1-05e29a57aad6")) {                    Plotly.newPlot(                        "16d3f9b6-ff8f-45ce-a5e1-05e29a57aad6",                        [{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003enum_non_mand=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"i1","bdata":"AQIDBAUGBwg="},"xaxis":"x","y":{"dtype":"f8","bdata":"HS67skjZ5D8cbN\u002fAhxrOP+MZ\u002fNHVr7U\u002fsc4nTKM+mD+MU9jQnqByP8Kgea2N7DU\u002f8Yi7vvo48j7xiLu++jiyPg=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data\u003cbr\u003enum_non_mand=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey data","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"i1","bdata":"AQIDBAUG"},"xaxis":"x","y":{"dtype":"f8","bdata":"rTw\u002fv5T85z\u002fNRsLWjSPHP8U\u002f1vcip6g\u002fi9xnNSDyjz\u002fsl9muHSVhPzOZVA79J28\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=unweighted survey\u003cbr\u003enum_non_mand=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"unweighted survey","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"unweighted survey","offsetgroup":"unweighted survey","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"i1","bdata":"AQIDBAUG"},"xaxis":"x","y":{"dtype":"f8","bdata":"NiZ7WlMH5z+lwD82JnvKP2rDeb2PUqs\u002fXRcyTzA8kD+QAyZArIJsP9atWo61V0k\u002f"},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1 ...

# %% [markdown]
# ## Number of non-mandatory tour by segment

# %% [raw]
# :::{.panel-tabset}
#
# ### person type

# %%
df_ptype_count = per_data.groupby(['source','ptype_label'])['person_weight'].sum().reset_index()

df_ptype_count.loc[df_ptype_count['source']=="model results"]
# Out:
#           source                     ptype_label  person_weight
# 0  model results             1: Full-Time Worker       547275.0
# 1  model results             2: Part-Time Worker       177335.0
# 2  model results           3: University Student        47107.0
# 3  model results    4: Non-Working Adult Age <65       485837.0
# 4  model results    5: Non-Working Adult Age 65+       340327.0
# 5  model results  6: High School Student Age 16+        46354.0
# 6  model results               7: Child Age 5-15       131392.0
# 7  model results                8: Child Age 0-4        65739.0

# %% [markdown]
# - tour rates

# %%
df_plot = non_m_tour_data. \
    groupby(['source','ptype_label','tour_category'])[['tour_weight']].sum().reset_index(). \
    merge(df_ptype_count, how='left', on=['source','ptype_label'])
df_plot['tour_cat_rate'] = df_plot['tour_weight']/df_plot['person_weight']

fig = px.bar(df_plot, x="ptype_label", y="tour_cat_rate", color="source",barmode="group",
             # facet_col="ptype_label",facet_col_wrap=2,
             title="non-mandatory tour rates by person type")
fig.for_each_annotation(lambda a: a.update(text=a.text.split("=")[-1]))
fig.update_layout(height=400, width=700)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="f04eeacc-64aa-4f8b-8866-4b31f02d603e" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("f04eeacc-64aa-4f8b-8866-4b31f02d603e")) {                    Plotly.newPlot(                        "f04eeacc-64aa-4f8b-8866-4b31f02d603e",                        [{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003eptype_label=%{x}\u003cbr\u003etour_cat_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":true,"textposition":"auto","x":["1: Full-Time Worker","2: Part-Time Worker","3: University Student","4: Non-Working Adult Age \u003c65","5: Non-Working Adult Age 65+","6: High School Student Age 16+","7: Child Age 5-15","8: Child Age 0-4"],"xaxis":"x","y":{"dtype":"f8","bdata":"kL0AU\u002ff49j\u002fj6eDRmn79P\u002fSVvT5Nfv0\u002fU1kfAlQd+T+j5dIHSZf3P55YIU2x7PM\u002ffzTfmm618j90FPQ+TinzPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data\u003cbr\u003eptype_label=%{x}\u003cbr\u003etour_cat_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey data","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":true,"textposition":"auto","x":["1: Full-Time Worker","2: Part-Time Worker","3: University Student","4: Non-Working Adult Age \u003c65","5: Non-Working Adult Age 65+","6: High School Student Age 16+","7: Child Age 5-15","8: Child Age 0-4"],"xaxis":"x","y":{"dtype":"f8","bdata":"kN4O\u002fGN28z\u002fVSb293x3xP\u002f7ia3eI5PE\u002fJKRK1yae9T9PdodZepX0P5uw+p+6TvM\u002fY48FkU+r6j\u002fUnn6tY+rvPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=unweighted survey\u003cbr\u003eptype_label=%{x}\u003cbr\u003etour_cat_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"unweighted survey","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"unweighted survey","offsetgroup":"unweighted survey","orientation":"v","showlegend":true,"textposition":"auto","x":["1: Full-Time Worker","2: Part-Time Worker","3: University Student","4: Non-Working Adult Age \u003c65","5: Non-Working Adult Age 65+","6: High School Student Age 16+","7: Child Age 5-15","8: Child Age 0-4"],"xaxis":"x","y":{"dtype":"f8","bdata":"y7Isy7Is9T96n+KSIVj3P9KpeZC7fvY\u002foPu5n\u002fu59z9f8RVf8RX2PxEREREREfE\u002fKkGeEuQp8T+xEzuxEzvxPw=="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.33 ...

# %% [markdown]
#  - number of non-mandatory tours

# %%
# number of mandatory tours
df_plot = per_data.groupby(['source','ptype_label','num_non_mand_simple'])['person_weight'].sum().reset_index()

df_plot['percentage'] = df_plot.groupby(['source','ptype_label'], group_keys=False)['person_weight']. \
    apply(lambda x: x / float(x.sum()))

fig = px.bar(df_plot, x="num_non_mand_simple", y="percentage", color="source",barmode="group",
             facet_col="ptype_label",facet_col_wrap=2,
             title="number of non-mandatory tours by person type")
fig.for_each_annotation(lambda a: a.update(text=a.text.split("=")[-1]))
fig.update_layout(height=1050, width=700)
fig.update_yaxes(tickformat=".1%")
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="6cd0fd44-e085-4b81-8ca8-9b651cf94d7b" class="plotly-graph-div" style="height:1050px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("6cd0fd44-e085-4b81-8ca8-9b651cf94d7b")) {                    Plotly.newPlot(                        "6cd0fd44-e085-4b81-8ca8-9b651cf94d7b",                        [{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003eptype_label=1: Full-Time Worker\u003cbr\u003enum_non_mand_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":true,"textposition":"auto","x":["1","2","3","4+"],"xaxis":"x7","y":{"dtype":"f8","bdata":"XQMK5gCd5T84r8f01SrOPytqbSq57rE\u002fCHLM7k5Okz8="},"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003eptype_label=2: Part-Time Worker\u003cbr\u003enum_non_mand_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["1","2","3","4+"],"xaxis":"x8","y":{"dtype":"f8","bdata":"FFitnm603D901uz11DnVP+7SstISd8Q\u002fBUBjEJixrj8="},"yaxis":"y8","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003eptype_label=3: University Student\u003cbr\u003enum_non_mand_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["1","2","3","4+"],"xaxis":"x5","y":{"dtype":"f8","bdata":"zqDOfp6x3D\u002fkHkQDjYzTP5laS\u002fKdKMo\u002fDpg8JixspT8="},"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003eptype_label=4: Non-Working Adult Age \u003c65\u003cbr\u003enum_non_mand_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["1","2","3","4+"],"xaxis":"x6","y":{"dtype":"f8","bdata":"E+q2BS8N5D8+JJqGyDrNPx3yyKmu3Lk\u002fnumWNpCIpj8="},"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003eptype_label=5: Non-Working Adult Age 65+\u003cbr\u003enum_non_mand_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["1","2","3","4+"],"xaxis":"x3","y":{"dtype":"f8","bdata":"y4kVQbPl5D91mCb1kLvPP6fX25u3irM\u002fYKSqxDFClz8="},"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003eptype_label=6: High School Student Age 16+\u003cbr\u003enum_non_mand_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["1","2","3","4+"],"xaxis":"x4","y":{"dtype":"f8","bdata":"PIwoIZao6T9jKTXbKhjEP5bEKuCxWKI\u002fHZG+AwXqdT8="},"yaxis":"y4","type":"bar"},{"alignmentgro ...

# %% [raw]
# ### auto ownership

# %% [markdown]
# - tour rates

# %%
df_auto_count = per_data.groupby(['source','auto_ownership_simple'])['person_weight'].sum().reset_index()

df_plot = non_m_tour_data. \
    groupby(['source','auto_ownership_simple','tour_category'])[['tour_weight']].sum().reset_index(). \
    merge(df_auto_count, how='left', on=['source','auto_ownership_simple'])
df_plot['tour_cat_rate'] = df_plot['tour_weight']/df_plot['person_weight']

fig = px.bar(df_plot, x="auto_ownership_simple", y="tour_cat_rate", color="source",barmode="group",
             # facet_col="ptype_label",facet_col_wrap=2,
             title="non-mandatory tour rates by auto ownership")
fig.for_each_annotation(lambda a: a.update(text=a.text.split("=")[-1]))
fig.update_layout(height=400, width=700)
fig.update_yaxes(tickformat=".1%")
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="ce4dece4-7434-4ad0-8d36-13e4cd2c9266" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("ce4dece4-7434-4ad0-8d36-13e4cd2c9266")) {                    Plotly.newPlot(                        "ce4dece4-7434-4ad0-8d36-13e4cd2c9266",                        [{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003etour_cat_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":{"dtype":"f8","bdata":"eE7I5D0D9T8tGSqoO873P8ofYIZkLvg\u002fPUpL+IIP+D9mPqCbWdz3Pw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003etour_cat_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey data","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":{"dtype":"f8","bdata":"\u002fA8EQ\u002f9P7z8UN8wBjdLwPweeBuuLSfQ\u002f73Yytk259D9NjMdxQ2v4Pw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=unweighted survey\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003etour_cat_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"unweighted survey","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"unweighted survey","offsetgroup":"unweighted survey","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":{"dtype":"f8","bdata":"27Zt27Zt9T9\u002fAJKsL8D2P+0JxauHL\u002fY\u002fMplMJpPJ9D9jOovpLKbzPw=="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outl ...

# %% [markdown]
# - number of non-mandatory tours

# %%
df_1 = per_data.groupby(['source','auto_ownership_simple','num_non_mand_simple'])['person_weight'].sum().reset_index()
df_1['percentage'] = df_1.groupby(['auto_ownership_simple','source'], group_keys=False)['person_weight']. \
    apply(lambda x: x / float(x.sum()))

fig = px.bar(df_1, x="num_non_mand_simple", y="percentage", color="source",barmode="group",
             facet_col="auto_ownership_simple",
             title="number of non-mandatory tours by auto ownership")
fig.for_each_annotation(lambda a: a.update(text=a.text.split("=")[-1]))
fig.update_layout(height=400, width=1200)
fig.update_yaxes(tickformat=".1%")
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="19287952-2687-463a-9f74-50ff7912308f" class="plotly-graph-div" style="height:400px; width:1200px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("19287952-2687-463a-9f74-50ff7912308f")) {                    Plotly.newPlot(                        "19287952-2687-463a-9f74-50ff7912308f",                        [{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003eauto_ownership_simple=0\u003cbr\u003enum_non_mand_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":true,"textposition":"auto","x":["1","2","3","4+"],"xaxis":"x","y":{"dtype":"f8","bdata":"EH+PQ6tH6D874guSdRzHP6p5B4F75Kk\u002fozFE9+e7hD8="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003eauto_ownership_simple=1\u003cbr\u003enum_non_mand_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["1","2","3","4+"],"xaxis":"x2","y":{"dtype":"f8","bdata":"ZThAJsja5D+9jWwRHZrOPyzbCM8LWbU\u002fxRhxcONxmj8="},"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003eauto_ownership_simple=2\u003cbr\u003enum_non_mand_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["1","2","3","4+"],"xaxis":"x3","y":{"dtype":"f8","bdata":"AJ5BPcqe5D8I7HIRdUvOPwTtU\u002fr8grY\u002fpivl4hu\u002fnz8="},"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003eauto_ownership_simple=3\u003cbr\u003enum_non_mand_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["1","2","3","4+"],"xaxis":"x4","y":{"dtype":"f8","bdata":"QibPsea15D\u002fevhsUVGDOPwguQ05i6LU\u002fpogw7P+enj8="},"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=model results\u003cbr\u003eauto_ownership_simple=4+\u003cbr\u003enum_non_mand_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model results","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model results","offsetgroup":"model results","orientation":"v","showlegend":false,"textposition":"auto","x":["1","2","3","4+"],"xaxis":"x5","y":{"dtype":"f8","bdata":"gYf8Zv335D\u002fNIHMEgcTNP6ufZOUBZrU\u002fxYpDZ0NEnT8="},"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data\u003cbr\u003eauto_ownership_simple=0\u003cbr\u003enum_non_mand_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey data","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey data","offsetgroup":"survey data","orientation":"v","showlegend":true,"textposition":"auto","x":["1","2","3","4+"],"xaxis":"x","y":{"dtype":"f8","bdata":"N7VaVfIG6D+ynnY3xknIP2tQOKBlFao\u002fhIUHsXBRgT8="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=survey data\u003cbr\u003eauto_ownership_simple=1\u0 ...

# %% [raw]
# :::
